# %% [markdown]
# `pip install scrapy`
# - `beautifulsoup` 에서는 사용 불가 셀레니움에서는 가능

# %% [markdown]
# ## xpath
# * css-selector 역할 해주는 문법

# %%
import scrapy
import requests
from scrapy.http import TextResponse # xpath 연습

# %% [markdown]
# ### xpath 사용방법
# * 다음 추천검색어 첫번째 xpath
# ```
# //*[@id="wrapSearch"]/div[3]/ul[3]/li[1]/a
# ```
# ```
# body #wrapSearch > div:nth-child(3) > ul:nth-child(3) > li:nth-child(1) > a
# ```
# **xpath** 구성 요소
# * `//` : 가장 상위 엘리먼트
# * `*` : 조건에 맞는 하위 엘리먼트를 모두 살펴봄
#     * `div .txt`
#     * 후손 선택자의 역할
# * `[@id="wrapSearch"]` : 조건 : `id`가 `wrapSearch`인 엘리먼트
# * `/` : 바로 아래 엘리먼트를 살펴봄.
#     * `div > .txt`
#     * 자식 선택자의 역할
# * `div[3]` : div 태그에서 3번째 엘리먼트를 선택
#     * 1부터 시작

# %%
from fake_useragent import UserAgent
# 웹 페이지 연결
headers = {"User-Agent" : UserAgent().chrome}
response = requests.get("http://corners.gmarket.co.kr/Bestsellers", headers = headers)
# TextResponse 객체 생성
text_response = TextResponse(response.url, body=response.text, encoding="utf-8")

# %%
text_response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a')
# Out:
# [<Selector xpath='//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a' data='<a class="itemname" href="http://item...'>]

# %% [markdown]
# `data` : xpath selector로 선택된 엘리먼트

# %%
# 텍스트만 선택하기
text_response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a/text()')
# Out:
# [<Selector xpath='//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a/text()' data='씨투엠에듀 도형학습지 플라토 유치~초등 단계별 선택구매(전4권)'>]

# %%
# TextResponse 객체에서 data만 가져오기
text_response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a/text()').extract()
# Out:
# ['씨투엠에듀 도형학습지 플라토 유치~초등 단계별 선택구매(전4권)']

# %%
# attribute만 가져오고 싶으면 @attribute 이름
text_response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a/@href').extract()
# Out:
# ['http://item.gmarket.co.kr/Item?goodscode=962002144&ver=637746459971454290']

# %%
text_response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li/a/text()').extract()
# Out:
# ['씨투엠에듀 도형학습지 플라토 유치~초등 단계별 선택구매(전4권)',
#  '[메디플라워]에트투스 트리트먼트 헤어팩 /헤어케어 아르간 1000ml',
#  '[은하수산]Ez cook 깔끔 손질 오징어 슬라이스 1kg (최대25%쿠폰)',
#  '[Gfresh]부산다대포 명물 순수해 진어묵탕 230gx5봉(장국포함)',
#  '시매쓰 영재사고력수학 1031 단계별 세트 선택구매',
#  '[해피콜][해피콜] 플렉스 팬 와이드 IH 22cm 3종 中 택1',
#  '반짝반짝캐치티니핑놀이터',
#  '청정우 차돌박이 (3초구이 샤브용) 250gX3팩',
#  '아넬라 15팩 시작과일A +3팩(바나나) 베이비페어특가',
#  '[온더바디]발을씻자 코튼 풋 샴푸 385ml 레몬+자몽+쿨링',
#  '모노시크/기모티셔츠/맨투맨/니트/상하세트/트레이닝',
#  '[아르떼(Arte)]아르떼 새부리형 마스크 KF94 100매 화이트 개별포장',
#  '[맥심]맥심 모카골드 커피믹스 400T : 커피는 맥심~',
#  '[정직한패드]20g X 400매 정직한 애견패드 강아지패드 배변패드',
#  '[아이클리어]15%+15% 종근당건강 아이클리어 눈사랑 루테인 3박스',
#  '엑소(EXXO) A4 복사용지(A4용지) 80g 2BOX(5000매)',
#  '(사회평론) 용선생의 시끌벅적 과학교실 26-27 전2권',
#  '(행사상품)경기미10KG 포 ',
#  '[별똥별]야물야물 보드그림책(기법책15권+보드책5권)-세이펜미포함',
#  '[살림백서]1+1 살림백서 세탁조 크리너 1 BOX (총 150g x 8개입)',
#  '[트루맘뉴클래스]트루맘 뉴클래스 퀸 슈퍼프리미엄 2단계 800g 3캔',
#  '[천호엔케어]키즈쑤욱 어린이 츄어블 프로바이오틱스 30정  2박스',
#  '서귀포인정 고당도 타이벡 감귤12brix 5kg 로얄(2S-M)',
#  '[애경]르샤트라 섬유유연제 피오니부케 1.6LX6개',
#  '무형광 미쁘 핸드타올  2겹5000매 페이퍼타올 핸드타월',
#  '무형광 5000매핸드타올 C 업소용 가정용 다용도 대용량',
#  '[밀크마일]밀크 귀욤 겨울신상 깜짝할인 상하복/티셔츠/레깅스외',
#  '팸퍼스 2박스 모음전 기저귀+신세계상품권 1만원',
#  '쇼인더룸 특가 기모맨투맨/티셔츠/빅사이즈/세트',
#  '[메가박스](메가박스) 2D 일반관 예매권',
#  '조선호텔 포기김치 8kg 100년 전통의 프리미엄 김치',
#  '[스파클](쿠폰적용가 11180원) 스파클생수 2L 30병',
#  '[동원에프앤비]동원 라이트 스탠다드 참치 150g 원터치 10개']

# %% [markdown]
# # Scrapy Project
# * scrapy 프로젝트 생성
# * scrapy 구조
# * 지마켓 베스트 상품 링크 수집, 링크 안에 있는 상세 페이지에서 수집

# %% [markdown]
# 기존 프로젝트를 삭제

# %%
#!rm -rf crawler

# %% [markdown]
# scrapy 프로젝트 생성하기
#  - `scrapy startproject <project name>`

# %%
# !scrapy startproject crawler
# Out:
# Error: scrapy.cfg already exists in C:\Users\td708\notebook\crawler

# %%
# !tree crawler
# Out:
# 폴더 PATH의 목록입니다.
# 볼륨 일련 번호가 00000070 4AE0:BBE4입니다.
# C:\USERS\TD708\NOTEBOOK\CRAWLER
# └─crawler
#     ├─spiders
#     │  └─__pycache__
#     └─__pycache__

# %% [markdown]
# scrapy 구조
# * spiders
#     * 어떤 웹서비스를 어떻게 크롤링 할 것인가에 대한 코드를 작성 ( .py파일 생성 )
#     * BeautifulSoup, Selenium, API 사용 등등
#     * 자동 쓰레드화
# * items.py
#     * 모델에 해당하는 코드, 저장하는 데이터의 자료구조를 설정
#     * 어떤 항목의 데이터를 크롤링해서 가지고 있을 것인가를 결정
#         * ex) 상세페이지 링크, 상품명, 원가, 할인가, 할인율, ...
# * pipelines.py
#     * 수집된 데이터(item)에 대한 처리
#     * db에 저장, slack에 알림, 등등...
# * settings.py
ver=637746459971610584',
#  'http://item.gmarket.co.kr/Item?goodscode=1510637585&ver=637746459971610584',
#  'http://item.gmarket.co.kr/Item?goodscode=1579104167&ver=637746459971610584']

# %% [markdown]
# 상세페이지 크롤링 테스트

# %%
# 첫 번째 링크를 이용해서 나머지 크롤링
link = links[0]

res = requests.get(link)
t_res = TextResponse(res.url, body=res.text, encoding="utf-8")

# 상품명
title = t_res.xpath('//*[@id="itemcase_basic"]/div[1]/h1/text()')[0].extract()
print(title)

# 원가
o_price = t_res.xpath('//*[@id="itemcase_basic"]/div[1]/p/span/span/text()')[0].extract()
o_price = o_price.replace(",", "")
print(o_price)

# 할인가
s_price = t_res.xpath('//*[@id="itemcase_basic"]/div[1]/p/span/strong/text()')[0].extract()
s_price = s_price.replace(",", "")
print(s_price)

# 할인율 - (할인가 / 원가) * 100
discount_rate = round((1 - (int(s_price) / int(o_price))) * 100, 2)
discount_rate = "{}%".format(discount_rate)
print(discount_rate)
# Out:
# 씨투엠에듀 도형학습지 플라토 유치~초등 단계별 선택구매(전4권)
# 48000
# 24000
# 50.0%

# %% [markdown]
# 2. items.py 작성

# %%
# !cat crawler/crawler/items.py
# Out:
# 'cat'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# %%writefile crawler/crawler/items.py
import scrapy


class CrawlerItem(scrapy.Item):
    title = scrapy.Field()
    o_price= scrapy.Field()
    s_price = scrapy.Field()
    discount_rate = scrapy.Field()
    link = scrapy.Field()
# Out:
# Overwriting crawler/crawler/items.py

# %% [markdown]
# #### 3. spider.py
# - 직접 파일을 만들어서 사용해야 한다.
# - 변경되면 안되는 변수와 메소드 ( 프레임 워크에서 지정한 규칙이기 때문에 바꾸면 안됨 )
#     - 변수 : `name, allow_domain, start_urls`
#     - 메소드 : `parse`

# %%
# %%writefile crawler/crawler/spiders/spider.py
import scrapy
from crawler.items import CrawlerItem

class Spider(scrapy.Spider):
    ### 바뀌면 안되는 변수들 ###
    name = "GmarketBestSellers" # 프로그램 이름
    allow_domain = ["gmarket.co.kr"] # 허용할 도메인
    start_urls = ["http://corners.gmarket.co.kr/Bestsellers"] # 처음 크롤링을 시작할 url 목록
    #################################
    
    # 바뀌면 안되는 함수
    def parse(self, response):
        # 상세 페이지 링크 목록 얻어오기
        links = response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li/a/@href').extract()
        
        # 페이지 하나하나 들어가면서 페이지 크롤링
        for link in links:
            # callback : 요청 완료 후 parsing 된 내용을 처리할 함수
            yield scrapy.Request(link, callback=self.page_content)
    
    # 메소드 이름은 바꿔도 상관 없으나 매개변수는 바꾸지 말 것
    def page_content(self, response): # response : 상세 페이지 결과
        item = CrawlerItem()
        
        # 상품명
        title = response.xpath('//*[@id="itemcase_basic"]/div[1]/h1/text()')[0].extract()



        # 할인가
        s_price = response.xpath('//*[@id="itemcase_basic"]/div[1]/p/span/strong/text()')[0].extract()
        s_price = s_price.replace(",", "")

                
        item["title"] = title
        item["s_price"] = s_price
        
        # 원가가 없고 할인가만 있는 경우가 있으면 원가에 할인가 넣어주기
        try: 
            # 원가
            o_price = response.xpath('//*[@id="itemcase_basic"]/div[1]/p/span/span/text()')[0].extract()
            o_price = o_price.replace(",", "")
            item["o_price"] = o_price
            
            item["discount_rate"] = discount_rate
        except:
            item["discount_rate"] = discount_rate
            
            item["o_price"] = s_price
            
                # 할인율 - (1 - (할인가 / 원가) * 100)
        discount_rate = round((1 - (int(item["s_price"]) / int(item["o_price"]))) * 100, 2)
        discount_rate = "{}%".format(discount_rate)
        
        item["discount_rate"] = discount_rate
        item["link"] = response.url
        
        
        yield item
# Out:
# Writing crawler/crawler/spiders/spider.py

# %% [markdown]
# #### 4. scrapy 실행

# %%
# %%writefile run.sh
#
# cd crawler
# scrapy crawl GmarketBestSellers
# Out:
# Overwriting run.sh

# %% [markdown]
# run.sh 파일에 대한 실행 권한 설정(리눅스 대응)

# %%
# !chmod +x run.sh
# Out:
# 'chmod'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# !./run.sh
# Out:
# '.'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %% [markdown]
# mac 용
# !source ./run.sh

# %% [markdown]
# 저장된 csv 불러오기

# %%
import pandas as pd
df_gbest = pd.read_csv("./crawler/GmarketBest.csv", encoding="utf-8")
df_gbest.head()
# Out:
#   discount_rate                                               link  o_price  \
# 0         9.96%  http://item.gmarket.co.kr/Item?goodscode=22771...    28300
# 1          0.0%  http://item.gmarket.co.kr/Item?goodscode=22397...    11900
# 2         50.0%  http://item.gmarket.co.kr/Item?goodscode=96200...    48000
# 3        66.67%  http://item.gmarket.co.kr/Item?goodscode=94101...    32700
# 4          5.0%  http://item.gmarket.co.kr/Item?goodscode=16552...   100000
#
#    s_price                                  title
# 0    25480                영실업  콩순이 NEW 아기하마 양치놀이
# 1    11900  달콤한 부사 햇 사과 4.5KG (26-30과)/13brix 이상
# 2    24000   씨투엠에듀 도형학습지 플라토 유치~초등 단계별 선택구매(전4권)
# 3    10900       로리니크 L04 단백질 헤어 영양크림 120ml 헤어앰플
# 4    95000          (카드가능) 기프트코드 10만원 / 구글 기프트카드

# %% [markdown]
# #### 5. Pipelines 설정
# * Item을 출력하기 전에 실행되는 코드를 정의

# %%
import requests
import json

def send_slack(msg):
    WEBHOOK_URL = "https://hooks.slack.com/services/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"
    
    payload = {
        "channel" : "#my-best-item",
        "username" : "aaa",
        "text" : msg
    }
    
    requests.post(WEBHOOK_URL, json.dumps(payload))

send_slack("테스트")

# %%
# %%writefile crawler/crawler/pipelines.py

import requests
import json


    
class CrawlerPipeline(object):
    
    def __send_slack(self, msg):
        WEBHOOK_URL = "https://hooks.slack.com/services/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"

        payload = {
            "channel" : "#my-best-item",
            "username" : "어느새부터코딩은안멋져",
            "text" : msg
        }

        requests.post(WEBHOOK_URL, json.dumps(payload))
    
    # 이름이 바뀌면 안되는 함수
    def process_item(self, item, spider):
        # item : spider에서 yield 되는 item
        # spider : 크롤러 객체
        
        keyword = "커피"
        print("="*100)
        print(item["title"], keyword)
        print("="*100)
        
        if keyword in item["title"]:
            msg = "{}, {}, {},".format(item["title"], item["s_price"], item["link"])
            
            self.__send_slack(msg)
        
        return item
# Out:
# Overwriting crawler/crawler/pipelines.py

# %% [markdown]
# #### setting.py 작성
# * 파이프라인 설정하기
# ```
# ITEM_PIPELINES = {
#     `crawler.pipelines.<파이프라인 클래스명>` : 우선순위 (정수형)
# }
# ```

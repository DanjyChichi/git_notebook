# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
MUSINSA_BEST_URL = "https://search.musinsa.com/ranking/best?u_cat_cd=002"

# %%
response = requests.get(MUSINSA_BEST_URL)
response
# Out:
# <Response [200]>

# %%
dom = BeautifulSoup(response.content, "html.parser")
dom
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title>상품 랭킹 | 무신사 스토어</title>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TXDSFSF');</script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="무신사 랭킹은 상품 매출, 판매 수량, 상품 조회 수, 작성 후기 수를 반영한 공식에 의해 선정됩니다.
# 무신사 스토어는 광고 목적으로 랭킹을 절대 임의 조작하지 않으므로 믿고 구매하셔도 됩니다." name="description"/>
# <script type="text/javascript">
#             var THIS_PAGE_GF = 'A';
#         </script>
# <link href="https://image.msscdn.net/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="648837775133366" id="fbAddId" property="fb:app_id"/>
# <meta content="website" id="fbOgType" property="og:type"/>
# <meta content="상품 랭킹 | 무신사 스토어" id="fbOgTitle" property="og:title"/>
# <meta content="https://image.msscdn.net/mfile_s01/fb/share_musinsa.png" id="fbOgImage" property="og:image"/>
# <meta content="무신사 랭킹은 상품 매출, 판매 수량, 상품 조회 수, 작성 후기 수를 반영한 공식에 의해 선정됩니다.
# 무신사 스토어는 광고 목적으로 랭킹을 절대 임의 조작하지 않으므로 믿고 구매하셔도 됩니다." id="fbOgDescription" property="og:description"/>
# <meta content="https://search.musinsa.com/ranking/best?u_cat_cd=002&amp;_gf=A" id="fbOgUrl" property="og:url"/>
# <link href="//static.msscdn.net/skin/musinsa/css/magazine_common.css?202112061746" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/store_common.css?202112061746" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/layout.min.css?202112061746" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/ui/musinsa/resources/common/css/icon.min.css?202112061746" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/guide.min.css?202112061746" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/style.min.css?202112061746" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/sub.css?202112061746" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/media_query.css?202112061746" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/new.css?202112061746" rel="stylesheet" type="text/css"/>
# <!-- 검색페이지에서 사용 -->
# <!-- Swiper -->
# <link href="//static.msscdn.net/swiper/swiper.min.css" rel="stylesheet" type="text/css"/>
# <!--jqModal-->
# <link href="//static.msscdn.net/skin/musinsa/css/jqModal.css?202112061746" rel="stylesheet" type="text/css"/>
# <!--//jqModal-->
# <!-- 유사 이미지 상품 검색 -->
# <link href="//static.msscdn.net/skin/musinsa/css/image_search.css?202112061746" rel="stylesheet" type="text/css"/>
# <!-- //유사 이미지 상품 검색 -->
# <link href="//static.msscdn.net/static/common/1.2.0/pc.css?202112061746" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/mfile_scr/layouts/community/css/musinsa_timeline.css?version=6.249" rel="stylesheet" type="text/css"/>
# <!-- 공통 레이아웃에서 사용함 -->
# <link href="//static.msscdn.net/ui/build/pc/css/common.css" rel="stylesheet" type="text/css"/>
# <!-- 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery-1.11.1.min.js?202112061746" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/base.js?202112061746" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/common.js?202112061746" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery.easing.js?202112061746" type="text/javascript"></script>
# <!--// 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/static/search/202112061746/js/common/pc/layout/common.js" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.cycle.all.js?202112061746" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/m_js/jquery-ui.min.js?202112061746" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.bxslider.js?202112061746" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/suggestions.js?202112061746" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/clipboard.min.js?202112061746" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/ui.js?202112061746" type="text/javascript"></script>
# <!-- Swiper -->
# <script src="//static.msscdn.net/swiper/swiper.min.js"></script>
# <!--jqModal-->
# <script src="//static.msscdn.net/skin/musinsa/js/jqModal.min.js?202112061746" type="text/javascript"></script>
# <!--//jqModal-->
# <!-- 유사 이미지 상품 검색 -->
# <script src="//static.msscdn.net/static/search/202112061746/js/common/pc/search/image_search_java.js" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.lazyload.min.js?202112061746" type="text/javascript"></script>
# <script src="//static.msscdn.net/static/common/1.2.0/chunk-vendors.js"></script>
# <script href="//static.msscdn.net/layouts/community/js/musinsa_timeline.new.js?version=6.249" type="text/javascript"></script>
# <script src="//static.msscdn.net/static/lib/blackhole/1.1.0/mssBlackholeSdk.js?202112061746"></script>
# <script>
#         var dataLayer = dataLayer || [];
#         dataLayer.push({
#             "productList" : {
#                 "email": "",
#                 // 조회 결과 중 상위 3개를 셋팅함. (goods_no-goods_sub)
#                 "list": []
#             }
#         });
#     </script>
# <script src="//static.msscdn.net/static/search/202112061746/js/common/pc/layout/config.js" type="text/javascript"></script>
# <script>
#         var uiConfig = {
#             service : 'musinsa',
#             isWusinsaService : false,
#             htmlTitle : '상품 랭킹 | 무신사 스토어',
#             isLoginYn: 'N',
#             memberGroupNo: '0',
#             total: '',
#             siteCode: 'musinsa',
#             headerSex: '',
#             globalFilter: 'A',
#             globalFilterWrapperCssName: 'musinsa',
#
#             searchFrontServiceUrl: 'https://search.musinsa.com/search/musinsa/',
#             searchApiUrl: 'https://search.musinsa.com',
#             serviceUrl : 'https://store.musinsa.com',
#             magazineUrl : 'https://magazine.musinsa.com',
#             storeUrl: 'https://store.musinsa.com',
#             mobileStoreUrl: 'https://m.store.musinsa.com',
#             wusinsaUrl : 'https://wusinsa.musinsa.com',
#             myPageUrl: 'https://my.musinsa.com',
#
#             likeApiUrl : 'https://like.musinsa.com/like',
#             goodsDetailUrl: '/app/goods/',
#             brandShopUrl: 'https://www.musinsa.com/brands/',
#
#             cssResourceUrl : '//static.msscdn.net',
#             httpImageResourceUrl : 'https://image.msscdn.net',
#             imageResourceUrl : 'https://image.msscdn.net',
#             staticResourceUrl : '//static.msscdn.net',
#             staticResourceVersion : '202112061746',
#
#             noImagePrefix: 'no_image_'
#         };
#
#         mss.ui.config.set(uiConfig);
#     </script>
# <!-- mss.ui : global config end -->
# <!-- mss.ui : gnb start -->
# <script src="//static.msscdn.net/static/search/202112061746/js/ajax.js" type="text/javascript"></script>
# </head>
# <body>
# <script>
#         var siteCode = "musinsa";
#
#         mss.ui.left = {
#             category: {
#                 dCatCd: "", // 선택된 카테고리 코드
#             },
#             menuType: 'list'
#         };
#
#         mss.ui.loggedIn = mss.ui.config.get().isLoginYn === 'Y';
#
#     </script>
# <div id="topCommonPc"></div>
# <script src="//static.msscdn.net/static/common/1.2.0/pc.js"></script>
# <div class="wrap">
# <div id="leftCommonPc"></div>
# <script src="//static.msscdn.net/static/common/1.2.0/lnb.js?202112061746"></script>
# <div class="right_area page-contents-best">
# <input name="d_cat_cd" type="hidden" value=""/>
# <div class="pagenation">
# <div class="nav_sub">
# <a href="https://store.musinsa.com">무신사 스토어</a>
# <span class="icon_entity">&gt;</span>
# <span>상품 랭킹</span>
# </div>
# <span class="txt_selected_division">all</span>
# </div>
# <div class="page_box">
# <div class="title_box">
# <h2 class="title-page">Ranking Shop</h2>
# <div class="tool-tabBtn">
# <a class="plain-btn btn active" href="https://store.musinsa.com/app/contents/bestranking">
#                                 상품
#                             </a><a class="plain-btn btn" href="https://store.musinsa.com/app/usr/brand_rank">
#                                 브랜드
#                             </a><a class="plain-btn btn" href="https://store.musinsa.com/app/usr/search_ranking">
#                                 검색어
#                             </a>
# </div>
# </div>
# <div class="page_intro">무신사 랭킹은 상품 매출, 판매 수량, 상품 조회 수, 작성 후기 수를 반영한 공식에 의해 선정됩니다.<br/>무신사 스토어는 광고 목적으로 랭킹을 절대 임의 조작하지 않으므로 믿고 구매하셔도 됩니다.</div>
# </div>
# <div class="n-banner-ranking">
# <a href="https://store.musinsa.com/app/cs/faq?q=%EB%9E%AD%ED%82%B9">
#                         무신사 랭킹을 알려드립니다.
#                         <em>
#                             자세히 보기
#                         </em>
# </a>
# </div>
# <form id="goodsRankForm">
# <div class="clear">
# <input name="period" type="hidden" value="now"/>
# <input name="age" type="hidden" value="ALL"/>
# <input name="mainCategory" type="hidden" value="002"/>
# <input name="subCategory" type="hidden" value=""/>
# <input name="leafCategory" type="hidden" value=""/>
# <input name="price" type="hidden" value=""/>
# <input name="golf" type="hidden" value="false"/>
# <input name="newProduct" type="hidden" value="false"/>
# <input name="exclusive" type="hidden" value="false"/>
# <input name="discount" type="hidden" value="false"/>
# <input name="soldOut" type="hidden" value="false"/>
# <input name="page" type="hidden" value="1"/>
# <input name="viewType" type="hidden" value="small"/>
# <div class="division_box hover_box box_division_group">
# <p class="article_title">
#             기간 구분
#         </p>
# <dl class="list_division_brand">
# <dt></dt>
# <dd>
# <ul class="division_reset">
# <li class="selected">
# <a href="javascript:mss.ranking.goods.filter.period('now');">실시간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('day');">일간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('week');">주간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('month');">월간</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.period('month_3');">3개월</a>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="division_box hover_box box_division_group">
# <p class="article_title">
#             대분류
#         </p>
# <dl class="list_division_brand">
# <dt>
# <div>
# <a href="javascript:mss.ranking.goods.filter.mainCategory(null);">
#                         전체
#                     </a>
# </div>
# </dt>
# <dd>
# <ul class="division_reset">
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('001');">상의</a>
# </li>
# <li class="selected">
# <a href="javascript:mss.ranking.goods.filter.mainCategory('002');">아우터</a>
# <a href="javascript:mss.ranking.goods.filter.mainCategory(null);">
# <span class="delete-btn-red">
#                                 X
#                             </span>
# </a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('003');">바지</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('020');">원피스</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('022');">스커트</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('018');">스니커즈</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('005');">신발</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('004');">가방</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('054');">여성 가방</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('017');">스포츠/용품</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('055');">골프용품</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('007');">모자</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('008');">양말/레그웨어</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('026');">속옷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('009');">선글라스/안경테</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('011');">액세서리</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('006');">시계</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('025');">주얼리</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('015');">뷰티</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('012');">디지털/테크</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('013');">생활/취미/예술</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('014');">책/음악/티켓</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.mainCategory('021');">반려동물</a>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="division_box hover_box box_division_group">
# <p class="article_title">
#             중분류
#         </p>
# <dl class="list_division_brand">
# <dt>
# <div class="selected">
# <a href="javascript:mss.ranking.goods.filter.subCategory(null);">
#                         전체
#                     </a>
# </div>
# </dt>
# <dd>
# <ul class="division_reset">
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002022');">후드 집업</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002001');">블루종/MA-1</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002002');">레더/라이더스 재킷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002025');">무스탕/퍼</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002017');">트러커 재킷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002003');">슈트/블레이저 재킷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002020');">카디건</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002019');">아노락 재킷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002023');">플리스/뽀글이</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002018');">트레이닝 재킷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002004');">스타디움 재킷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002008');">환절기 코트</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002007');">겨울 싱글 코트</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002024');">겨울 더블 코트</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002009');">겨울 기타 코트</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002013');">롱패딩/롱헤비 아우터</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002012');">숏패딩/숏헤비 아우터</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002016');">패딩 베스트</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002021');">베스트</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002014');">사파리/헌팅 재킷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002006');">나일론/코치  재킷</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.subCategory('002015');">기타 아우터</a>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="division_box hover_box box_division_price box_division_group">
# <p class="article_title">
#             가격
#         </p>
# <dl class="list_division_brand">
# <dt>
# <div class="selected">
# <a href="javascript:mss.ranking.goods.filter.price(null);">
#                         전체
#                     </a>
# </div>
# </dt>
# <dd>
# <ul class="division_price division_reset">
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('~50000');">5만원 이하</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('50000~100000');">5~10만원</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('100000~200000');">10~20만원</a>
# </li>
# <li>
# <a href="javascript:mss.ranking.goods.filter.price('200000~300000');">20~30만원</a>
# </li>
# <li class="last">
# <a href="javascript:mss.ranking.goods.filter.price('300000~');">30만원 이상</a>
# </li>
# <li class="division_search_box search_price">
# <input class="division_search_input" maxlength="9" name="priceMin" title="최소 가격 검색" type="text" value=""/><span>원 ~</span>
# <input class="division_search_input" maxlength="9" name="priceMax" title="최대 가격 검색" type="text" value=""/><span>원</span>
# <span class="division_search_btn" onclick="mss.ranking.goods.filter.customPrice();">검색</span>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# </div>
# <div class="right_contents hover_box">
# <div class="select_option">
# <span class="keyword_selected">
# <a href="javascript:mss.ranking.goods.filter.mainCategory(null);">
#             대분류 : 아우터
#             <span class="delete-btn-red">X</span>
# </a>
# </span>
# </div>
# <div class="boxed-list-wrapper rank-shop">
# <div class="sorter-box box">
# <p class="box_renew">
#                         19분 전 갱신
#                     </p>
# <div class="pagination">
# <div class="wrapper">
# <a class="fa fa-angle-double-left paging-btn btn first" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">첫 페이지</label>
# </a>
# <a class="fa fa-angle-left paging-btn btn prev" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">이전</label>
# </a>
# <a class="paging-btn btn active" href="javascript:mss.ranking.goods.page(1);">1</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(2);">2</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(3);">3</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(4);">4</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(5);">5</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(6);">6</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(7);">7</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(8);">8</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(9);">9</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(10);">10</a>
# <a class="fa fa-angle-right paging-btn btn next" href="javascript:mss.ranking.goods.page(11);">
# <label style="display:none">다음</label>
# </a>
# <a class="fa fa-angle-double-right paging-btn btn last" href="javascript:mss.ranking.goods.page(100);">
# <label style="display:none">마지막 페이지</label>
# </a>
# </div>
# </div>
# </div>
# <div class="thumbType_box box">
# <span class="image_view_select">
# <a class="view_select_small selected" href="javascript:mss.ranking.goods.viewType('small');" title="작은 이미지">
#                             작은 이미지
#                         </a>
# <a class="view_select_big" href="javascript:mss.ranking.goods.viewType('large');" title="큰 이미지">
#                             큰 이미지
#                         </a>
# </span>
# <span class="counter check_box_area">
# <label><input onchange="mss.ranking.goods.filter.check('newProduct', this.checked);" type="checkbox"/>신상품</label>
# </span>
# <span class="counter check_box_area">
# <label><input onchange="mss.ranking.goods.filter.check('exclusive', this.checked);" type="checkbox"/>단독</label>
# </span>
# <span class="counter check_box_area">
# <label><input onchange="mss.ranking.goods.filter.check('discount', this.checked);" type="checkbox"/>세일</label>
# </span>
# <span class="counter check_box_area">
# <label><input onchange="mss.ranking.goods.filter.check('soldOut', this.checked);" type="checkbox"/>품절 포함</label>
# </span>
# <span class="counter check_box_area">
# <label><input onchange="mss.ranking.goods.filter.check('golf', this.checked);" type="checkbox"/>골프</label>
# </span>
# <span class="counter box_num_goods">
# <label class="is_goods">상품 수 : 53,722개</label>
# </span>
# <span class="pagingNumber">
# <span class="totalPagingNum">100</span>
#         페이지 중
#         <span class="currentPagingNum">1</span>
#         페이지
#
# </span>
# </div>
# <div class="list-box box">
# <ul class="snap-article-list boxed-article-list article-list center list goods_small_media8" id="goodsRankList">
# <li class="li_box" data-goods-no="2037173">
# <p class="n-label label-default txt_num_rank">
#             1위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2037173?loc=goods_rank">
# <img alt="스파오(SPAO) [허니푸퍼] 베이직 푸퍼_SPJPB4TC11" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210722/2037173/2037173_14_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/spao">스파오</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2037173?loc=goods_rank" title="[허니푸퍼] 베이직 푸퍼_SPJPB4TC11">
#
#
#
#                         [허니푸퍼] 베이직 푸퍼_SPJPB4TC11
#                     </a>
# </p>
# <p class="price">
# <del>69,900원</del>
#                     64,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2037173', '2037173', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2037173" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2037173', '2037173', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">64,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">3,848</span>
# </p>
# <p class="txt_cnt_like goods_like_2037173 hide" id="like_2037173">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2037173" onclick="viewOption3(this, '2037173', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2037173" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2064478">
# <p class="n-label label-default txt_num_rank">
#             2위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2064478?loc=goods_rank">
# <img alt="라퍼지스토어(LAFUDGESTORE) [리뉴얼 ver.][3M 신슐레이트]오리지널 M-1965 피쉬테일 파카_Original Khaki" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210813/2064478/2064478_3_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/lafudgestore">라퍼지스토어</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2064478?loc=goods_rank" title="[리뉴얼 ver.][3M 신슐레이트]오리지널 M-1965 피쉬테일 파카_Original Khaki">
#
#
#
#                         [이동휘 착용][리뉴얼 ver.][3M 신슐레이트]오리지널 M-1965 피쉬테일 파카_Original Khaki
#                     </a>
# </p>
# <p class="price">
# <del>138,000원</del>
#                     99,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2064478', '2064478', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2064478" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2064478', '2064478', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">99,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 94.0%"></span>
# </span>
# <span class="count">7,364</span>
# </p>
# <p class="txt_cnt_like goods_like_2064478 hide" id="like_2064478">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2064478" onclick="viewOption3(this, '2064478', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2064478" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2037171">
# <p class="n-label label-default txt_num_rank">
#             3위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2037171?loc=goods_rank">
# <img alt="스파오(SPAO) [허니푸퍼] 리버서블 푸퍼_SPJDB4VC14" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210722/2037171/2037171_18_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/spao">스파오</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2037171?loc=goods_rank" title="[허니푸퍼] 리버서블 푸퍼_SPJDB4VC14">
#
#
#
#                         [허니푸퍼] 리버서블 푸퍼_SPJDB4VC14
#                     </a>
# </p>
# <p class="price">
# <del>89,900원</del>
#                     69,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2037171', '2037171', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2037171" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2037171', '2037171', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">69,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">4,022</span>
# </p>
# <p class="txt_cnt_like goods_like_2037171 hide" id="like_2037171">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2037171" onclick="viewOption3(this, '2037171', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2037171" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1173366">
# <p class="n-label label-default txt_num_rank">
#             4위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1173366?loc=goods_rank">
# <img alt="라퍼지스토어(LAFUDGESTORE) [무봉제]덕다운 심리스 미니멀 푸퍼 숏패딩_Black" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20191001/1173366/1173366_6_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/lafudgestore">라퍼지스토어</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1173366?loc=goods_rank" title="[무봉제]덕다운 심리스 미니멀 푸퍼 숏패딩_Black">
#
#
#
#                         [무봉제]덕다운 심리스 미니멀 푸퍼 숏패딩_Black
#                     </a>
# </p>
# <p class="price">
# <del>143,000원</del>
#                     89,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1173366', '1173366', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1173366" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1173366', '1173366', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">89,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 93.0%"></span>
# </span>
# <span class="count">6,044</span>
# </p>
# <p class="txt_cnt_like goods_like_1173366 hide" id="like_1173366">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1173366" onclick="viewOption3(this, '1173366', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1173366" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2105483">
# <p class="n-label label-default txt_num_rank">
#             5위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2105483?loc=goods_rank">
# <img alt="노스페이스(THE NORTH FACE) NC1DM73A 고 프리 하이브리드 다운 코트 EX" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210902/2105483/2105483_1_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/thenorthface">노스페이스</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2105483?loc=goods_rank" title="NC1DM73A 고 프리 하이브리드 다운 코트 EX">
#
#
#
#                         NC1DM73A 고 프리 하이브리드 다운 코트 EX
#                     </a>
# </p>
# <p class="price">
# <del>299,000원</del>
#                     269,100원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2105483', '2105483', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2105483" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2105483', '2105483', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">269,100원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 94.0%"></span>
# </span>
# <span class="count">277</span>
# </p>
# <p class="txt_cnt_like goods_like_2105483 hide" id="like_2105483">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2105483" onclick="viewOption3(this, '2105483', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2105483" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1611891">
# <p class="n-label label-default txt_num_rank">
#             6위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1611891?loc=goods_rank">
# <img alt="라퍼지 포 우먼(LAFUDGE FOR WOMAN) 울리치 트렌치 맥코트_Black" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200918/1611891/1611891_3_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/lafudgeforwomen">라퍼지 포 우먼</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1611891?loc=goods_rank" title="울리치 트렌치 맥코트_Black">
#
#
#
#                         울리치 트렌치 맥코트_Black
#                     </a>
# </p>
# <p class="price">
# <del>163,000원</del>
#                     108,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1611891', '1611891', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1611891" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1611891', '1611891', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">108,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 91.0%"></span>
# </span>
# <span class="count">2,632</span>
# </p>
# <p class="txt_cnt_like goods_like_1611891 hide" id="like_1611891">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1611891" onclick="viewOption3(this, '1611891', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1611891" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1535337">
# <p class="n-label label-default txt_num_rank">
#             7위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1535337?loc=goods_rank">
# <img alt="코드그라피(CODEGRAPHY) [PRAUDEN] 유틸리티 덕다운 푸파 숏패딩_쿨그레이" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200803/1535337/1535337_4_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/codegraphy">코드그라피</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1535337?loc=goods_rank" title="[PRAUDEN] 유틸리티 덕다운 푸파 숏패딩_쿨그레이">
#
#
#
#                         [PRAUDEN] 유틸리티 덕다운 푸파 숏패딩_쿨그레이
#                     </a>
# </p>
# <p class="price">
#
#                     124,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1535337', '1535337', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1535337" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1535337', '1535337', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">124,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 95.0%"></span>
# </span>
# <span class="count">4,262</span>
# </p>
# <p class="txt_cnt_like goods_like_1535337 hide" id="like_1535337">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1535337" onclick="viewOption3(this, '1535337', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1535337" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2059072">
# <p class="n-label label-default txt_num_rank">
#             8위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2059072?loc=goods_rank">
# <img alt="케이투(K2) 씬에어(THINAIR) ECO LONG 다운 자켓 미드나잇 블랙" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210811/2059072/2059072_1_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/k2">케이투</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2059072?loc=goods_rank" title="씬에어(THINAIR) ECO LONG 다운 자켓 미드나잇 블랙">
#
#
#
#                         씬에어(THINAIR) ECO LONG 다운 자켓 미드나잇 블랙
#                     </a>
# </p>
# <p class="price">
# <del>380,000원</del>
#                     335,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2059072', '2059072', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2059072" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2059072', '2059072', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">335,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">258</span>
# </p>
# <p class="txt_cnt_like goods_like_2059072 hide" id="like_2059072">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2059072" onclick="viewOption3(this, '2059072', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2059072" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="865862">
# <p class="n-label label-default txt_num_rank">
#             9위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-musinsa icon-reverse">무신사 단독</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/865862?loc=goods_rank">
# <img alt="무신사 스탠다드(MUSINSA STANDARD) 캐시미어 블렌드 오버사이즈 싱글 코트 [블랙]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20180921/865862/865862_3_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/musinsastandard">무신사 스탠다드</a>
# </p>
# <span class="icon_img_gift">
# <img alt="gift" src="https://image.msscdn.net/skin/musinsa/images/ico_gift.gif"/>
# </span>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/865862?loc=goods_rank" title="캐시미어 블렌드 오버사이즈 싱글 코트 [블랙]">
#
#
#
#                         캐시미어 블렌드 오버사이즈 싱글 코트 [블랙]
#                     </a>
# </p>
# <p class="price">
#
#                     139,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_865862', '865862', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_865862" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_865862', '865862', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">139,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 95.0%"></span>
# </span>
# <span class="count">16,044</span>
# </p>
# <p class="txt_cnt_like goods_like_865862 hide" id="like_865862">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol865862" onclick="viewOption3(this, '865862', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol865862" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1616798">
# <p class="n-label label-default txt_num_rank">
#             10위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1616798?loc=goods_rank">
# <img alt="커버낫(COVERNAT) RDS 롱 다운 파카 블랙" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200922/1616798/1616798_2_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/covernat">커버낫</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1616798?loc=goods_rank" title="RDS 롱 다운 파카 블랙">
#
#
#
#                         RDS 롱 다운 파카 블랙
#                     </a>
# </p>
# <p class="price">
# <del>269,000원</del>
#                     215,200원
#                 </p>
# <p class="mu-icon mu-icon-coupon">
# <span class="txt_discount_price">-10,760원</span>
# </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1616798', '1616798', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1616798" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1616798', '1616798', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">215,200원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">1,280</span>
# </p>
# <p class="txt_cnt_like goods_like_1616798 hide" id="like_1616798">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1616798" onclick="viewOption3(this, '1616798', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1616798" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2072441">
# <p class="n-label label-default txt_num_rank">
#             11위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-reverse label-boutique">부티크</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2072441?loc=goods_rank">
# <img alt="스톤아일랜드(STONE ISLAND) 남성 와펜 패치 가먼트 다이 크링클 렙스 나일론 다운 TC 후드 패딩 - 블루 / 751540123V0020" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210819/2072441/2072441_1_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/stoneisland">스톤아일랜드</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2072441?loc=goods_rank" title="남성 와펜 패치 가먼트 다이 크링클 렙스 나일론 다운 TC 후드 패딩 - 블루 / 751540123V0020">
# <strong class="txt_reserve">새벽배송</strong>
#                         남성 와펜 패치 가먼트 다이 크링클 렙스 나일론 다운 TC 후드 패딩 - 블루 / 751540123V0020
#                     </a>
# </p>
# <p class="price">
# <del>1,395,000원</del>
#                     1,048,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2072441', '2072441', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2072441" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2072441', '2072441', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">1,048,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 100.0%"></span>
# </span>
# <span class="count">21</span>
# </p>
# <p class="txt_cnt_like goods_like_2072441 hide" id="like_2072441">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2081554">
# <p class="n-label label-default txt_num_rank">
#             12위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2081554?loc=goods_rank">
# <img alt="노스페이스(THE NORTH FACE) NJ1DM62A 남성 1996 에코 눕시 자켓" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210823/2081554/2081554_2_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/thenorthface">노스페이스</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2081554?loc=goods_rank" title="NJ1DM62A 남성 1996 에코 눕시 자켓">
#
#
#
#                         NJ1DM62A 남성 1996 에코 눕시 자켓
#                     </a>
# </p>
# <p class="price">
#
#                     299,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2081554', '2081554', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2081554" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2081554', '2081554', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">299,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">1,854</span>
# </p>
# <p class="txt_cnt_like goods_like_2081554 hide" id="like_2081554">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2081554" onclick="viewOption3(this, '2081554', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2081554" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="914738">
# <p class="n-label label-default txt_num_rank">
#             13위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/914738?loc=goods_rank">
# ...
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2175979?loc=goods_rank">
# <img alt="로어즈(LORES) Puffer Jacket - Black" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20211013/2175979/2175979_2_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/lores">로어즈</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2175979?loc=goods_rank" title="Puffer Jacket - Black">
#
#
#
#                         Puffer Jacket - Black
#                     </a>
# </p>
# <p class="price">
#
#                     279,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2175979', '2175979', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2175979" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2175979', '2175979', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">279,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 100.0%"></span>
# </span>
# <span class="count">1</span>
# </p>
# <p class="txt_cnt_like goods_like_2175979 hide" id="like_2175979">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2175979" onclick="viewOption3(this, '2175979', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2175979" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2134077">
# <p class="n-label label-default txt_num_rank">
#             86위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2134077?loc=goods_rank">
# <img alt="디스이즈네버댓(THISISNEVERTHAT) PERTEX® T Down Jacket Bandana Black" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210915/2134077/2134077_2_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/thisisneverthat">디스이즈네버댓</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2134077?loc=goods_rank" title="PERTEX® T Down Jacket Bandana Black">
#
#
#
#                         PERTEX® T Down Jacket Bandana Black
#                     </a>
# </p>
# <p class="price">
# <del>189,000원</del>
#                     132,300원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2134077', '2134077', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2134077" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2134077', '2134077', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">132,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 95.0%"></span>
# </span>
# <span class="count">132</span>
# </p>
# <p class="txt_cnt_like goods_like_2134077 hide" id="like_2134077">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2134077" onclick="viewOption3(this, '2134077', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2134077" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1593395">
# <p class="n-label label-default txt_num_rank">
#             87위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1593395?loc=goods_rank">
# <img alt="마크 곤잘레스(MARK GONZALES) 엔젤 RDS 코듀로이 다운 숏푸퍼 블랙" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200909/1593395/1593395_5_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/markgonzales">마크 곤잘레스</a>
# </p>
# <span class="icon_img_gift">
# <img alt="gift" src="https://image.msscdn.net/skin/musinsa/images/ico_gift.gif"/>
# </span>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1593395?loc=goods_rank" title="엔젤 RDS 코듀로이 다운 숏푸퍼 블랙">
#
#
#
#                         엔젤 RDS 코듀로이 다운 숏푸퍼 블랙
#                     </a>
# </p>
# <p class="price">
# <del>189,000원</del>
#                     151,200원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1593395', '1593395', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1593395" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1593395', '1593395', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">151,200원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">160</span>
# </p>
# <p class="txt_cnt_like goods_like_1593395 hide" id="like_1593395">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1593395" onclick="viewOption3(this, '1593395', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1593395" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="2198318">
# <p class="n-label label-default txt_num_rank">
#             88위
#
#         </p>
# <div class="box-icon-right">
# <span class="icon-box-limited icon-reverse">한정 판매</span>
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2198318?loc=goods_rank">
# <img alt="드로우핏(DRAW FIT) MTR 마를린 더블 코트 [BLACK]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20211026/2198318/2198318_2_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/drawfit">드로우핏</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2198318?loc=goods_rank" title="MTR 마를린 더블 코트 [BLACK]">
#
#
#
#                         MTR 마를린 더블 코트 [BLACK]
#                     </a>
# </p>
# <p class="price">
# <del>398,000원</del>
#                     358,200원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2198318', '2198318', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2198318" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2198318', '2198318', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">358,200원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 91.0%"></span>
# </span>
# <span class="count">12</span>
# </p>
# <p class="txt_cnt_like goods_like_2198318 hide" id="like_2198318">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol2198318" onclick="viewOption3(this, '2198318', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol2198318" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1515904">
# <p class="n-label label-default txt_num_rank">
#             89위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1515904?loc=goods_rank">
# <img alt="내셔널지오그래픽(NATIONALGEOGRAPHIC) N204MDW930 타루가 남성 RDS 덕 다운 점퍼 C GREY" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20200715/1515904/1515904_5_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/nationalgeographic">내셔널지오그래픽</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1515904?loc=goods_rank" title="N204MDW930 타루가 남성 RDS 덕 다운 점퍼 C GREY">
#
#
#
#                         N204MDW930 타루가 남성 RDS 덕 다운 점퍼 C GREY
#                     </a>
# </p>
# <p class="price">
# <del>359,000원</del>
#                     251,300원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1515904', '1515904', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1515904" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1515904', '1515904', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">251,300원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">152</span>
# </p>
# <p class="txt_cnt_like goods_like_1515904 hide" id="like_1515904">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1515904" onclick="viewOption3(this, '1515904', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1515904" style="display:none;"></div>
# </div>
# </li>
# <li class="li_box" data-goods-no="1758197">
# <p class="n-label label-default txt_num_rank">
#             90위
#
#         </p>
# <div class="box-icon-right">
# </div>
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1758197?loc=goods_rank">
# <img alt="라퍼지스토어(LAFUDGESTORE) [매트블랙] 버핑레더 미니멀 포켓 블루종_Matt Black" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210121/1758197/1758197_4_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/lafudgestore">라퍼지스토어</a>
# </p>
# <span class="icon_img_gift">
# <img alt="gift" src="https://image.msscdn.net/skin/musinsa/images/ico_gift.gif"/>
# </span>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1758197?loc=goods_rank" title="[매트블랙] 버핑레더 미니멀 포켓 블루종_Matt Black">
# <strong class="txt_reserve">12 / 21 배송</strong>
#
#                         [매트블랙] 버핑레더 미니멀 포켓 블루종_Matt Black
#                     </a>
# </p>
# <p class="price">
# <del>94,000원</del>
#                     69,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1758197', '1758197', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_1758197" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_1758197', '1758197', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">69,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 96.0%"></span>
# </span>
# <span class="count">3,940</span>
# </p>
# <p class="txt_cnt_like goods_like_1758197 hide" id="like_1758197">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>
# <div class="option">
# <p class="option_btn">
# <a href="#pol1758197" onclick="viewOption3(this, '1758197', '0');">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="#pol1758197" style="display:none;"></div>
# </div>
# </li>
# </ul>
# </div>
# <div class="pagingNumber-box box">
# <span class="pagingNumber">
# <span class="totalPagingNum">100</span>
#         페이지 중
#         <span class="currentPagingNum">1</span>
#         페이지
#
# </span>
# </div>
# <div class="pagination-box box">
# <div class="pagination bottom">
# <div class="wrapper">
# <a class="fa fa-angle-double-left paging-btn btn first" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">첫 페이지</label>
# </a>
# <a class="fa fa-angle-left paging-btn btn prev" href="javascript:mss.ranking.goods.page(null);">
# <label style="display:none">이전</label>
# </a>
# <a class="paging-btn btn active" href="javascript:mss.ranking.goods.page(1);">1</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(2);">2</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(3);">3</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(4);">4</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(5);">5</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(6);">6</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(7);">7</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(8);">8</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(9);">9</a><a class="paging-btn btn" href="javascript:mss.ranking.goods.page(10);">10</a>
# <a class="fa fa-angle-right paging-btn btn next" href="javascript:mss.ranking.goods.page(11);">
# <label style="display:none">다음</label>
# </a>
# <a class="fa fa-angle-double-right paging-btn btn last" href="javascript:mss.ranking.goods.page(100);">
# <label style="display:none">마지막 페이지</label>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# <script src="//static.msscdn.net/static/search/202112061746/js/common/pc/contents/goods.js" type="text/javascript"></script>
# <div class="ui-layer-close fixed"></div>
# <meta content="NqB0BDAEWJTvAPCCxzrckJYnS7-xJILFU40FvSmh5S8" name="google-site-verification"/>
# <div id="footerCommonPc"></div>
# <div class="ui-layer-close fixed"></div>
# </div>
# </div>
# </body>
# <script>
#         $(function() {
#             removeGfParameter();
#             $('img.lazyload').lazyload();
#         });
#     </script>
# <script src="//static.msscdn.net/static/search/202112061746/js/ranking/goods_pc.js" type="text/javascript"></script>
# </html>

# %%
#m_best_top = dom.select("#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div.list-box.box")
#best_list = m_best_top[0].select("#goodsRankList")
#best_list.select("#goodsRankList > li.li_box")

# %%
m_best_top = dom.select("#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div.list-box.box")
best_list = m_best_top[0].select("#goodsRankList > li.li_box > div.li_inner")
best_list[0]
# Out:
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/2037173?loc=goods_rank">
# <img alt="스파오(SPAO) [허니푸퍼] 베이직 푸퍼_SPJPB4TC11" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210722/2037173/2037173_14_125.jpg" src="https://image.msscdn.net/0.gif"/>
# </a>
# </div>
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/spao">스파오</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2037173?loc=goods_rank" title="[허니푸퍼] 베이직 푸퍼_SPJPB4TC11">
#
#
#
#                         [허니푸퍼] 베이직 푸퍼_SPJPB4TC11
#                     </a>
# </p>
# <p class="price">
# <del>69,900원</del>
#                     64,900원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2037173', '2037173', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2037173" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2037173', '2037173', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">64,900원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">3,848</span>
# </p>
# <p class="txt_cnt_like goods_like_2037173 hide" id="like_2037173">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>
# </div>

# %%
item_best1 = dom.select("#goodsRankList > li.li_box > div.li_inner > div.article_info")[7]
item_best1
# Out:
# <div class="article_info">
# <p class="item_title">
# <a href="https://www.musinsa.com/brands/k2">케이투</a>
# </p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/2059072?loc=goods_rank" title="씬에어(THINAIR) ECO LONG 다운 자켓 미드나잇 블랙">
#
#
#
#                         씬에어(THINAIR) ECO LONG 다운 자켓 미드나잇 블랙
#                     </a>
# </p>
# <p class="price">
# <del>380,000원</del>
#                     335,000원
#                 </p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_2059072', '2059072', '0');">
#                     MEMBERSHIP PRICE<span class="fr">▼</span>
# </p>
# <div class="member_price" id="sPrice_2059072" style="display:none; z-index: 9999;">
# <p>무신사 회원가
#                         <span class="fr">
# <a href="javascript:viewMemberPrice2('sPrice_2059072', '2059072', '0');">X</a>
# </span>
# </p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;">
# <span>&gt;</span>
#                             비회원<span class="txt_price_member">335,000원</span>
# </li>
# </ul>
# </div>
# <p class="point">
# <span class="img-score">
# <span class="bar" style="width: 97.0%"></span>
# </span>
# <span class="count">258</span>
# </p>
# <p class="txt_cnt_like goods_like_2059072 hide" id="like_2059072">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>
# </div>

# %%
# 브랜드명
item_best1.select_one("p.item_title > a").text
# Out:
# '케이투'

# %%
item_name = item_best1.select_one("p.list_info > a").text
item_name
# Out:
# '\n                        \n                        \n                        \n                        씬에어(THINAIR) ECO LONG 다운 자켓 미드나잇 블랙\n                    '

# %%
# 상품명
params = item_name.strip()
item_name = params
item_name
# Out:
# '씬에어(THINAIR) ECO LONG 다운 자켓 미드나잇 블랙'

# %%
# 별점
item_best1.select_one("p.point > span.img-score > span")
a = item_best1.select_one("p.point > span.img-score > span").get("style")
a
# Out:
# 'width: 97.0%'

# %%
print(item_best1.select_one("p.point > span.img-score > span"))
# Out:
# <span class="bar" style="width: 97.0%"></span>

# %%
# 별점
item_grade = item_best1.select_one("p.point > span.img-score > span").get("style")
item_grade = item_grade.split(" ")
item_grade = item_grade[1].replace("%", "")
item_grade = float(item_grade) / 20
item_grade
# Out:
# 4.85

# %%
# 상품코드
item_link = item_best1.select_one("p.list_info > a").get("href")
item_code = item_link.split("/")
item_code = item_code[5].split("?")
item_code = item_code[0]
item_code
# Out:
# '2059072'

# %%
# 상품상세페이지 링크
print(item_link)
# Out:
# https://store.musinsa.com/app/goods/2059072?loc=goods_rank

# %%
# 좋아요 수 #like_2037173 > span
item_like = item_best1.select_one("#like_{}".format(item_code))
item_like
# Out:
# <p class="txt_cnt_like goods_like_2059072 hide" id="like_2059072">
# <img alt="좋아요" src="https://image.msscdn.net/skin/musinsa/images/icon_like_small_on.png"/>
# <span name="count"></span>
# </p>

# %%
# 가격
item_price = item_best1.select_one("p.price").text
item_price = item_price.replace(" ", "")
item_price = item_price.replace("\n", "")
item_price = item_price.replace(",", "")
item_price = item_price.replace("원", "")
item_price = int(item_price)
item_price
# Out:
# 380000335000

# %%
from urllib.parse import urlparse, parse_qs

# %%
parsed_url = urlparse(link_item1)
parsed_url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9864/850120776.py in <module>
# ----> 1 parsed_url = urlparse(link_item1)
#       2 parsed_url
#
# NameError: name 'link_item1' is not defined

# %%
url_query = parsed_url.path.split("/")
url_query = url_query[2 : 4]
url_query = "=".join(url_query)
url_query
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9864/1189858924.py in <module>
# ----> 1 url_query = parsed_url.path.split("/")
#       2 url_query = url_query[2 : 4]
#       3 url_query = "=".join(url_query)
#       4 url_query
#
# NameError: name 'parsed_url' is not defined

# %%
parsed_query = parse_qs(url_query)
parsed_query
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9864/2913222431.py in <module>
# ----> 1 parsed_query = parse_qs(url_query)
#       2 parsed_query
#
# NameError: name 'url_query' is not defined

# %%
result = []
parsed_url = parsed_url[2].split("/")
parsed_url = parsed_url[3]
parsed_url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9864/2754293454.py in <module>
#       1 result = []
# ----> 2 parsed_url = parsed_url[2].split("/")
#       3 parsed_url = parsed_url[3]
#       4 parsed_url
#
# NameError: name 'parsed_url' is not defined

# %%
print(dom.select_one("#goodsRankList > li.li_box > div.li_inner > div.list_img > a > img").get("data-original"))
# Out:
# https://image.msscdn.net/images/goods_img/20210722/2037173/2037173_14_125.jpg

# %%
img_url = dom.select_one("#goodsRankList > li.li_box > div.li_inner > div.list_img > a > img").get("data-original")
img_url
# Out:
# 'https://image.msscdn.net/images/goods_img/20210722/2037173/2037173_14_125.jpg'

# %%
from urllib.request import urlretrieve


urlretrieve(img_url, item_code+".jpg") # 임의로 png라고 적어준다.
# Out:
# ('2059072.jpg', <http.client.HTTPMessage at 0x266c75052b0>)

# %%
# !mkdir musinsa_images

# %%
for item in best_list[1].select("div.article_info"):
    item_name = item.select_one("p.list_info > a").text
    params = item_name.strip()
    item_name = params
    item_brand = item.select_one("p.item_title > a").text
    item_link = item.select_one("p.list_info > a").get("href")
    
    

    parsed_url = urlparse(item_link)
    url_query = parsed_url.path.split("/")
    url_query = url_query[2 : 4]
    url_query = "=".join(url_query)
    parsed_query = parse_qs(url_query)
    item_code = parsed_query["goods"][0]
    
    img_url = item.select_one("div.list_img > a > img").get("data-original")
    urlretrieve(img_url, "./musinsa_images/"+item_code+".jpg")
    
    if item.select_one("p.point > span.img-score > span") == None:
        pass
    else:
        item_grade = item.select_one("p.point > span.img-score > span").get("style")
        item_grade = item_grade.split(" ")
        item_grade = item_grade[1].replace("%", "")
        item_grade = float(item_grade) / 20
        item_grade
    
    print("상품명 :", item_name, "브랜드 :", item_brand, "\n", "제품 링크 :", item_link, "별점", item_grade,"점", "상품 코드 :", item_code)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9864/1860305395.py in <module>
#      15     item_code = parsed_query["goods"][0]
#      16
# ---> 17     img_url = item.select_one("div.list_img > a > img").get("data-original")
#      18     urlretrieve(img_url, "./musinsa_images/"+item_code+".jpg")
#      19
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
#goodsRankList > li:nth-child(3) > div.li_inner > div.list_img > a > img

# %%
#goodsRankList > li:nth-child(1) > div.li_inner > div.article_info > p.price

# %%
#goodsRankList > li:nth-child(2) > div.li_inner > div.article_info > p.point > span.count

# %%
#goodsRankList > li:nth-child(2) > div.li_inner > div.article_info > p.list_info > a

# %%
#goodsRankList > li:nth-child(3) > div.li_inner > div.list_img > a > img

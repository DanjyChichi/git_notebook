# %% [markdown]
# !conda install -c conda-forge geohash2

# %%
import requests
import geohash2
import time
import pandas as pd

# 검색할 주소의 위도와 경도를 얻어내기
addr = "삼산동" # 여기 바꾸세요
url = "https://apis.zigbang.com/search?q={}".format(addr)
response = requests.get(url)
data = response.json()["items"][0]
lat, lng = data["lat"], data["lng"]

# geohash 만들어서 해당 지역의 매물을 검색할 수 있도록 함.
geohash = geohash2.encode(lat, lng, precision=5)
house_type = "아파트" # 여기 바꾸세요

url = "https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={}&rent_gteq=0&service_type_eq={}".format(geohash,house_type)
response = requests.get(url)

# item id가 나온다.
item_ids = [data["item_id"] for data in response.json()["items"]]

url = "https://apis.zigbang.com/v2/items/list"
params = {
    "domain": "zigbang",
    "item_ids": item_ids,
    "withCoalition": "true",
}
response = requests.post(url, data=params)
datas = response.json()["items"]

datas
# Out:
# [{'section_type': None,
#   'item_id': 28756928,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/28756928/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 36000,
#   'rent': 0,
#   'size_m2': 94.8,
#   '공급면적': {'m2': 94.8, 'p': '28.7'},
#   '전용면적': {'m2': 60, 'p': '18.2'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '7',
#   'floor_string': '7',
#   'building_floor': '11',
#   'title': '🏠부평 일신동 신축급관리 안심가능 위치 좋습니다🏠',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 일신동',
#   'random_location': {'lat': 37.48560399066518, 'lng': 126.74276876163414},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 일신동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '8',
#   'reg_date': '2021-11-08T10:20:29+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29343170,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29343170/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 36000,
#   'rent': 0,
#   'size_m2': 63.17,
#   '공급면적': {'m2': 63.17, 'p': '19.1'},
#   '전용면적': {'m2': 60, 'p': '18.2'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '7',
#   'floor_string': '7',
#   'building_floor': '10',
#   'title': '⭐일신동 18년식 넓은 아파트  막힘없는 뷰⭐',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 일신동',
#   'random_location': {'lat': 37.48562020909373, 'lng': 126.74335545260527},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 일신동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-11-06T14:26:12+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29670013,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29670013/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 65,
#   'size_m2': 49.25,
#   '공급면적': {'m2': 49.25, 'p': '14.9'},
#   '전용면적': {'m2': 36.36, 'p': '11'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '9',
#   'title': '💕💕깔끔✔️부천역세권💕',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.4853247323468, 'lng': 126.77869810671642},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5.7',
#   'reg_date': '2021-12-03T13:20:53+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29613923,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29613923/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 39,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '9',
#   'title': '🌈🌈부천역🌈🌈초저렴!!깔끔한 오피스텔 😘',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48585052387987, 'lng': 126.77716502590735},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6.2',
#   'reg_date': '2021-11-29T18:32:11+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29617610,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29617610/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 39,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '9',
#   'title': '🌈🌈부천역 도보5분 최저가 도전 빌트인 깔끔',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485840410938636, 'lng': 126.77719300615955},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-30T10:48:52+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29660418,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29660418/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 50,
#   'rent': 50,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '9',
#   'title': '☀☀☀부천역 신축 빌트인 끝장! 붙박이장2개!공실!',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.4853610513864, 'lng': 126.7778136910012},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-02T16:59:11+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29665062,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29665062/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 39,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 16.53, 'p': '5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '9',
#   'title': '🟥🟥🟥풀옵션 이중보안 가성비최고 역세권 그라하시티',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485854002478725, 'lng': 126.777167684431},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-03T10:01:21+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29669531,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29669531/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 50,
#   'rent': 50,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '9',
#   'title': '🌈🌈부천역 신축 빌트인 예술 단기 가능~공실!!',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48585139151493, 'lng': 126.77778760719032},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-03T12:56:20+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29619155,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29619155/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 65,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 33.06, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '8',
#   'floor_string': '8',
#   'building_floor': '9',
#   'title': '역세권 깔끔하고 환한 투룸',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48586287341566, 'lng': 126.77808412523461},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-03T13:06:08+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29361364,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29361364/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 20,
#   'size_m2': 19.83,
#   '공급면적': {'m2': 19.83, 'p': '6'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '4',
#   'title': '역 가깝고 밝은 원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48589690965804, 'lng': 126.77774914125924},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-11-08T16:00:31+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29381169,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29381169/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 35,
#   'size_m2': 37.1,
#   '공급면적': {'m2': 37.1, 'p': '11.2'},
#   '전용면적': {'m2': 20.7, 'p': '6.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '🔷🔷🔷가성비최고🎀풀옵션/보안좋은집/즉시입주',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485477765079054, 'lng': 126.7788369766587},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-10T10:41:51+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29573641,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29573641/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 45,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '☀☀☀부천역 신축을 보증금 100으로??공실!!당장입주가능',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485489681625324, 'lng': 126.77881253019594},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-02T16:21:54+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29608806,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29608806/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 42,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '☀☀☀부천역 초신축 공실!보증금 100! 단기가능!상태A급',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48597732504254, 'lng': 126.778164389875},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-12-02T16:20:58+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29608818,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29608818/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 40,
#   'rent': 45,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '☀☀☀부천역 신축 무보증!!당장 입주 가능~희귀템!!',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48545187213557, 'lng': 126.7788091068791},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-03T12:56:12+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29613527,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29613527/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 40,
#   'rent': 45,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 16.53, 'p': '5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '🌈🌈오늘 단 하루 이벤트!!보안 좋아요!! 단기가능O',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485463797734575, 'lng': 126.77819843877352},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-29T18:11:24+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29617637,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29617637/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 45,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '🌈🌈부천역 !!최저가 도전 !! 자주식 주차가능합니다!',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48596633953655, 'lng': 126.77880221358402},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-30T10:49:37+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29625422,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29625422/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 35,
#   'size_m2': 37.1,
#   '공급면적': {'m2': 37.1, 'p': '11.2'},
#   '전용면적': {'m2': 20.7, 'p': '6.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '🟦🟥🟩 FULL옵션 원룸 부천역 3분 즉시입주가능',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48597976068562, 'lng': 126.77883928842189},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-30T16:30:00+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29657974,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29657974/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 40,
#   'size_m2': 26.45,
#   '공급면적': {'m2': 26.45, 'p': '8'},
#   '전용면적': {'m2': 14.88, 'p': '4.5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '💖💖단기가능한 깔끔한 오피스텔 💖💖',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48548148256024, 'lng': 126.77820021636525},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-02T15:32:15+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29667166,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29667166/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 42,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 16.53, 'p': '5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '🌈🌈2개월 가능O 자주식 무료주차! 이런게 선착순',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48547459341705, 'lng': 126.77816265979061},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-03T11:21:35+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29620496,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29620496/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 80,
#   'size_m2': 99.17,
#   '공급면적': {'m2': 99.17, 'p': '30'},
#   '전용면적': {'m2': 95.86, 'p': '29'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '올 리모델링된 주택',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48611307330303, 'lng': 126.7780976862762},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-03T13:06:43+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29620576,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29620576/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 50,
#   'size_m2': 42.98,
#   '공급면적': {'m2': 42.98, 'p': '13'},
#   '전용면적': {'m2': 39.67, 'p': '12'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '깔끔한 역세권 투룸',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48611495655514, 'lng': 126.7780756187081},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-03T13:06:26+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29652285,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29652285/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 75,
#   'size_m2': 69.42,
#   '공급면적': {'m2': 69.42, 'p': '21'},
#   '전용면적': {'m2': 66.12, 'p': '20'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '*초역세권*공간넓음*',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48611470779652, 'lng': 126.77746197558899},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-02T11:40:15+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29652308,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29652308/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 50,
#   'size_m2': 46.28,
#   '공급면적': {'m2': 46.28, 'p': '14'},
#   '전용면적': {'m2': 42.98, 'p': '13'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '5',
#   'title': '~💕초역세권~💕깔끔~💕',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.4861077276729, 'lng': 126.77812450374455},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-02T11:40:51+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29504941,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29504941/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 60,
#   'size_m2': 51.32,
#   '공급면적': {'m2': 51.32, 'p': '15.5'},
#   '전용면적': {'m2': 34.89, 'p': '10.6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '10',
#   'title': '🔷🔷🔷풀옵션1.5룸🎀보안.관리잘되는건물/빠른입주가능',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48565750007787, 'lng': 126.77970073250307},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-11-20T11:49:33+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29545836,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29545836/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 60,
#   'size_m2': 51.32,
#   '공급면적': {'m2': 51.32, 'p': '15.5'},
#   '전용면적': {'m2': 34.89, 'p': '10.6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '10',
#   'title': '🟦🟥🟩 풀옵션 오피스텔 부천역 3분거리 보안 잘되는집',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48613474378549, 'lng': 126.77972779613262},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-11-24T09:44:21+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29554172,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29554172/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 60,
#   'size_m2': 51.32,
#   '공급면적': {'m2': 51.32, 'p': '15.5'},
#   '전용면적': {'m2': 34.89, 'p': '10.6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '10',
#   'title': '🟥🟥🟥풀옵션 이중보안 초역세권 가성비최고 GOOD',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48565369024558, 'lng': 126.7797355312292},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-11-24T15:47:38+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29432788,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29432788/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 35,
#   'size_m2': 34.05,
#   '공급면적': {'m2': 34.05, 'p': '10.3'},
#   '전용면적': {'m2': 17.54, 'p': '5.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '❤🧡💛💚💙 쁘띠하임  화이트복층 부천대 부천역',
#   'is_first_movein': None,
#   'room_type': '03',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485792052992466, 'lng': 126.78010058877055},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-15T10:44:46+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29554699,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29554699/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 52,
#   'rent': 52,
#   'size_m2': 37.95,
#   '공급면적': {'m2': 37.95, 'p': '11.5'},
#   '전용면적': {'m2': 19.55, 'p': '5.9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '❤🧡💛💚💙쁘띠하임 부천역 화이트복층 깨끗 부천대',
#   'is_first_movein': None,
#   'room_type': '03',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48628049616565, 'lng': 126.78009396246908},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-24T16:09:27+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29592747,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29592747/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 200,
#   'rent': 35,
#   'size_m2': 34.05,
#   '공급면적': {'m2': 34.05, 'p': '10.3'},
#   '전용면적': {'m2': 17.54, 'p': '5.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '❤🧡💛💚💙화이트 복층 풀옵션 쁘띠하임 깔끔한방 풀옵',
#   'is_first_movein': None,
#   'room_type': '03',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48581349502463, 'lng': 126.78075708187293},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-27T15:51:15+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29652353,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29652353/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 38,
#   'size_m2': 34.05,
#   '공급면적': {'m2': 34.05, 'p': '10.3'},
#   '전용면적': {'m2': 17.54, 'p': '5.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '💕단기6개월도 가능💕저렴&&풀옵션✔️복층❤️❤️',
#   'is_first_movein': None,
#   'room_type': '03',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48580815284805, 'lng': 126.78073221966343},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6.5',
#   'reg_date': '2021-12-02T11:42:05+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29663168,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29663168/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 37,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '1',
#   'floor_string': '1',
#   'building_floor': '3',
#   'title': '부천역5분 주방분리 깔끔한방 가심비좋은방',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48637657368188, 'lng': 126.77814302867075},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-12-02T19:12:15+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29529687,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29529687/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 37,
#   'size_m2': 29.75,
#   '공급면적': {'m2': 29.75, 'p': '9'},
#   '전용면적': {'m2': 29.75, 'p': '9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '1',
#   'floor_string': '1',
#   'building_floor': '4',
#   'title': '♣♣ 밝고 깨끗하고 넓은 주방분리형',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.486349341751456, 'lng': 126.77878647638624},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-11-22T18:48:46+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29647348,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29647348/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 27,
#   'size_m2': 12.55,
#   '공급면적': {'m2': 12.55, 'p': '3.8'},
#   '전용면적': {'m2': 12.55, 'p': '3.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '5',
#   'title': '❤️중동, 부천역 원룸 ❤️ 도시형생활주택 ❤️',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.486354903688536, 'lng': 126.77298492846403},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-12-01T20:05:07+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29526461,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29526461/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 35,
#   'size_m2': 12.66,
#   '공급면적': {'m2': 12.66, 'p': '3.8'},
#   '전용면적': {'m2': 12.66, 'p': '3.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '5',
#   'title': '❤️중동역 원룸월세❤️임대료 인하❤️',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.485852656023134, 'lng': 126.77360093248359},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-11-22T16:33:54+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29653225,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29653225/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 35,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '원룸단기 3개월  보100-35,50-38만 부천역5분',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48646313797377, 'lng': 126.77736203217918},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-12-03T09:45:43+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29317638,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29317638/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 30,
#   'size_m2': 23.1405,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '6',
#   'floor_string': '6',
#   'building_floor': '7',
#   'title': '부천역 5분 대로변 엘리베이터있는 깔끔한 원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48604772125586, 'lng': 126.77822785819556},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-11-06T13:37:26+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29613564,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29613564/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 45,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '5',
#   'title': '💙주차가능!!통베란다 있는 남향 눈부신방 💖💗',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48606067686395, 'lng': 126.77808004672166},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-29T18:13:13+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29550892,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29550892/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 35,
#   'size_m2': 16.52,
#   '공급면적': {'m2': 16.52, 'p': '5'},
#   '전용면적': {'m2': 16.52, 'p': '5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '5',
#   'floor_string': '5',
#   'building_floor': '5',
#   'title': '🟦🟥🟩베란다 + FULL옵션 원룸 즉시입주가능',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48609566361846, 'lng': 126.77812177073545},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-11-24T13:20:54+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29626609,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29626609/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 45,
#   'size_m2': 24.79,
#   '공급면적': {'m2': 24.79, 'p': '7.5'},
#   '전용면적': {'m2': 24.79, 'p': '7.5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '5',
#   'title': '🌈🌈🌈채광 끝판왕 통배란다 오픈형 원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48607245004797, 'lng': 126.77750309115551},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-30T17:25:57+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29645681,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29645681/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 45,
#   'size_m2': 26.45,
#   '공급면적': {'m2': 26.45, 'p': '8'},
#   '전용면적': {'m2': 26.45, 'p': '8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '5',
#   'title': '🔷🔷🔷통베란다.남동향🎀채광굿/깨끗.풀옵션/즉시입주',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48654950330356, 'lng': 126.77809299102361},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-01T18:05:20+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29663456,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29663456/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 35,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '5',
#   'floor_string': '5',
#   'building_floor': '5',
#   'title': '♣♣ 해잘드는 초특가원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.4865645134342, 'lng': 126.77812873402188},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-02T19:45:47+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29424818,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29424818/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 50000,
#   'rent': 0,
#   'size_m2': 70.54,
#   '공급면적': {'m2': 70.54, 'p': '21.3'},
#   '전용면적': {'m2': 67.34, 'p': '20.4'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '13',
#   'title': '⭕⭐부천 중동역 신축풀옵션 빌라형아파트⭐⭕',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48608699289276, 'lng': 126.76870644993879},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '4',
#   'reg_date': '2021-11-13T16:22:39+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29434991,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29434991/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 43500,
#   'rent': 0,
#   'size_m2': 93.85,
#   '공급면적': {'m2': 93.85, 'p': '28.4'},
#   '전용면적': {'m2': 59.65, 'p': '18'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '13',
#   'title': '❣💜💛중동역 도보5분💚❤1호선 초역세권💙🧡❣',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.486108669823196, 'lng': 126.76932582522981},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '4',
#   'reg_date': '2021-11-15T11:49:38+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29478610,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29478610/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 49000,
#   'rent': 0,
#   'size_m2': 100.4,
#   '공급면적': {'m2': 100.4, 'p': '30.4'},
#   '전용면적': {'m2': 67.34, 'p': '20.4'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '13',
#   'title': '✅중동역✅다양한학군✅편의시설✅학세권',
#   'is_first_movein': None,
#   'room_type': '06',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48660430100515, 'lng': 126.76931995380926},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-11-19T12:37:44+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29492512,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29492512/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 42500,
#   'rent': 0,
#   'size_m2': 85.34,
#   '공급면적': {'m2': 85.34, 'p': '25.8'},
#   '전용면적': {'m2': 59.65, 'p': '18'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '6',
#   'floor_string': '6',
#   'building_floor': '13',
#   'title': '🌈신축첫입주apt🌈잔여세대엑기스🌈중동역도보5분남향집',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.4860969450108, 'lng': 126.7693402663892},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-11-19T12:03:32+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29596582,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29596582/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 33900,
#   'rent': 0,
#   'size_m2': 74,
#   '공급면적': {'m2': 74, 'p': '22.4'},
#   '전용면적': {'m2': 59.65, 'p': '18'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '7',
#   'floor_string': '7',
#   'building_floor': '13',
#   'title': '👏실입주금15000💕중동역320미터💖명품신축아파트매물',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.486605141112534, 'lng': 126.7687234501591},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-11-28T11:07:47+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29647142,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29647142/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 41500,
#   'rent': 0,
#   'size_m2': 87.19,
#   '공급면적': {'m2': 87.19, 'p': '26.4'},
#   '전용면적': {'m2': 60.23, 'p': '18.2'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '6',
#   'floor_string': '6',
#   'building_floor': '13',
#   'title': '🔴❤️신축 역세권아파트❤️🔴💜🔵학군밀집지역🔵💜',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.486100654762716, 'lng': 126.76873339002739},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-12-01T19:33:30+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29675362,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29675362/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 43500,
#   'rent': 0,
#   'size_m2': 85.95,
#   '공급면적': {'m2': 85.95, 'p': '26'},
#   '전용면적': {'m2': 59.5, 'p': '18'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '14',
#   'title': '❤️신축첫입주❤️즉시입주가능❤️목돈없이마련가능',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.486122537403936, 'lng': 126.7693199568007},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-03T17:16:36+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29648163,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29648163/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 26500,
#   'rent': 0,
#   'size_m2': 85,
#   '공급면적': {'m2': 85, 'p': '25.7'},
#   '전용면적': {'m2': 63.16, 'p': '19.1'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '5',
#   'title': '🍀중동역 역세권 인프라 굿 이사비100프로!🍀',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48617865874155, 'lng': 126.7697312021719},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-12-03T10:22:55+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29602754,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29602754/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 45,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '13',
#   'title': '🌈🌈부천역 초 신축 큰대로변!!🌈🌈안심귀가 가능💑',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48673763671618, 'lng': 126.78028349449235},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-11-29T11:10:31+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29640776,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29640776/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 40,
#   'size_m2': 38.18,
#   '공급면적': {'m2': 38.18, 'p': '11.5'},
#   '전용면적': {'m2': 18, 'p': '5.4'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '13',
#   'title': '🔷🔷🔷신축급 풀옵션🎀큰길.안전귀가/깔끔한 오피스텔',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48674007732216, 'lng': 126.78030282787644},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-01T15:23:06+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29655523,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29655523/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 45,
#   'size_m2': 46.28,
#   '공급면적': {'m2': 46.28, 'p': '14'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '13',
#   'title': '☀☀☀부천역 초 신축 가온팰리스 상태 내부상태 초A급^^',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48625043046841, 'lng': 126.78090078068558},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-02T16:19:55+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29663027,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29663027/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 10500,
#   'rent': 0,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 18, 'p': '5.4'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '13',
#   'title': '부천역3분\r\n전세대출기능한집',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.486725492074584, 'lng': 126.78026139200823},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '8',
#   'reg_date': '2021-12-02T18:58:11+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29532105,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29532105/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 26000,
#   'rent': 0,
#   'size_m2': 56.2,
#   '공급면적': {'m2': 56.2, 'p': '17'},
#   '전용면적': {'m2': 37, 'p': '11.2'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '5',
#   'title': '위치 채광최고 좋은 따스한 느낌의 쓰리룸',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48627875039931, 'lng': 126.77557968327478},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-11-26T11:20:18+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29632471,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29632471/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 26100,
#   'rent': 0,
#   'size_m2': 75.21,
#   '공급면적': {'m2': 75.21, 'p': '22.8'},
#   '전용면적': {'m2': 49.06, 'p': '14.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '5',
#   'title': '중동3룸ㅣ준신축ㅣ최저실입ㅣ역세권ㅣ이사비전부지원',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48694806552342, 'lng': 126.76996474969835},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-12-03T10:38:08+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29618433,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29618433/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 13500,
#   'rent': 0,
#   'size_m2': 92.56,
#   '공급면적': {'m2': 92.56, 'p': '28'},
#   '전용면적': {'m2': 38, 'p': '11.5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '1',
#   'floor_string': '1',
#   'building_floor': '4',
#   'title': '■ 급!!매물 바로 입주가능/부개역세권/쓰리룸',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 부개동',
#   'random_location': {'lat': 37.48645353729561, 'lng': 126.74148937341312},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 부개동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-11-30T11:16:31+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29471191,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29471191/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 50,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 33.06, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '부천역도보5분거리 깔끔한1.5룸.',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48698432428995, 'lng': 126.77982932915332},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '4',
#   'reg_date': '2021-12-03T13:05:23+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29589741,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29589741/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 28,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 33.06, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '5',
#   'title': '월세 500/28',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부평구 부개동',
#   'random_location': {'lat': 37.48700933417679, 'lng': 126.74010227441109},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 부개동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-11-27T12:39:16+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29450347,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29450347/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 54,
#   'size_m2': 52.89,
#   '공급면적': {'m2': 52.89, 'p': '16'},
#   '전용면적': {'m2': 26.45, 'p': '8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '5',
#   'title': '☀☀☀부천역 초 신축!! 공실~큰대로변~! 깔끔인테리어!',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.4870344023842, 'lng': 126.77878068413722},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
# ...
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '삼산동 삼산고등학교 인근 인테리어 예쁜 집 금방나가요',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52053001287038, 'lng': 126.74680261787745},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-01T15:26:47+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29643406,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29643406/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 39,
#   '공급면적': {'m2': 39, 'p': '11.8'},
#   '전용면적': {'m2': 33, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '삼산고인근 특올수리 채광좋은 쓰리룸',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520022624793825, 'lng': 126.74680640994625},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0.5',
#   'reg_date': '2021-12-01T16:52:02+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29645361,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29645361/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 38.09,
#   '공급면적': {'m2': 38.09, 'p': '11.5'},
#   '전용면적': {'m2': 32, 'p': '9.7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '12월 3일 확인매물✅대단지, 고속도로 진입용이, 방3개',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52053258867951, 'lng': 126.74677215066373},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-03T10:12:24+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29654925,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29654925/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 32, 'p': '9.7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '💖인증매물💖 전체 리모델링 채광좋고 투자가치 좋은집',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520525714525974, 'lng': 126.7468070003295},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-02T13:27:15+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29657741,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29657741/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 33, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '❤️삼산동 한길초교 인접❤️신혼집/특올수리 3룸❤️',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520527474025364, 'lng': 126.746775496566},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-12-02T15:29:26+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29668189,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29668189/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 38.07,
#   '공급면적': {'m2': 38.07, 'p': '11.5'},
#   '전용면적': {'m2': 32.87, 'p': '9.9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '🌈삼산고인근🌈특올수리🌈 채광굿',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52004778605724, 'lng': 126.74676235041561},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-03T11:57:18+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29603997,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29603997/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '5',
#   'title': '삼산동 유일한 중기청 100 가능한 특올수리 빌라',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52022965801949, 'lng': 126.74653702271365},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-11-29T12:24:42+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29608853,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29608853/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '특올수리 . 투룸 . 중기청가능 .lh불가',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52022396243929, 'lng': 126.74591481947678},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-11-29T16:10:36+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29636072,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29636072/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 26.45, 'p': '8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '부천 출퇴근 선호도 1위지역,중기청100가능,LH불가',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52072310053902, 'lng': 126.74655250034624},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-01T12:36:41+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29637771,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29637771/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 26.45, 'p': '8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '삼산동 내부특올수리진행 깔끔한투룸매물 중기청100가능',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52025140320044, 'lng': 126.74654017165165},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-01T13:37:54+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29640301,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29640301/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '40',
#   'title': '삼산동 올수리 완료 한집 중기청 가능 안심가능 최다보유',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520719908447305, 'lng': 126.74654093590487},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-01T15:06:29+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29643250,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29643250/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 35,
#   '공급면적': {'m2': 35, 'p': '10.6'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '삼산고등학교 인근 특올수리 채광좋은투룸',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52023248491506, 'lng': 126.74653124009349},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0.5',
#   'reg_date': '2021-12-01T16:46:26+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29654590,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29654590/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 35.08,
#   '공급면적': {'m2': 35.08, 'p': '10.6'},
#   '전용면적': {'m2': 29.4, 'p': '8.9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '★특올수리/구조가 좋음/위치가 좋음★',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52022084583256, 'lng': 126.74590069978441},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-02T13:10:08+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29658779,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29658779/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 49.59,
#   '공급면적': {'m2': 49.59, 'p': '15'},
#   '전용면적': {'m2': 38, 'p': '11.5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '🔴학세권🟠삼산체육관역🟡고속도로인접🟢채광좋은투룸🔵',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520220424868924, 'lng': 126.7459301184709},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-02T16:00:40+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29662079,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29662079/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 32,
#   '공급면적': {'m2': 32, 'p': '9.7'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '[오늘 확인]✅삼산고,대단지빌라,소액투자,특올수리,채광짱!',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520233975340865, 'lng': 126.74652903458811},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-03T17:00:34+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29667315,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29667315/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 32.48,
#   '공급면적': {'m2': 32.48, 'p': '9.8'},
#   '전용면적': {'m2': 29.4, 'p': '8.9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '😍삼산고인근😍깨끗😍특올수리😍',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520730484208414, 'lng': 126.74652852686748},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-03T11:26:32+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29493481,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29493481/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 23600,
#   'rent': 0,
#   'size_m2': 104.81,
#   '공급면적': {'m2': 104.81, 'p': '31.7'},
#   '전용면적': {'m2': 64.88, 'p': '19.6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '14',
#   'title': '19년식 준신축 3룸 전세 지하주차장+단지형오피스텔',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '계양구 작전동',
#   'random_location': {'lat': 37.525939164427605, 'lng': 126.73956221158554},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '인천시 계양구 작전동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '8',
#   'reg_date': '2021-11-19T15:12:39+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29586375,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29586375/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 3500,
#   'rent': 45,
#   'size_m2': 66.12,
#   '공급면적': {'m2': 66.12, 'p': '20'},
#   '전용면적': {'m2': 59.5, 'p': '18'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '14',
#   'title': '작전역 차량 5분 현대아파트 인근 벍은 구조 투룸 신혼집',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '계양구 작전동',
#   'random_location': {'lat': 37.526564756416604, 'lng': 126.74067110341856},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '인천시 계양구 작전동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '13',
#   'reg_date': '2021-11-27T09:50:51+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29581493,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29581493/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 40,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '베란다 별도 있는 풀옵션 원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 오정동',
#   'random_location': {'lat': 37.52929715815049, 'lng': 126.78179710359417},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 오정동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-11-26T15:56:22+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29570299,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29570299/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 40,
#   'size_m2': 26.45,
#   '공급면적': {'m2': 26.45, 'p': '8'},
#   '전용면적': {'m2': 26.45, 'p': '8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '깨끗하고 신축건물인 풀옵션원룸',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 오정동',
#   'random_location': {'lat': 37.52881366431649, 'lng': 126.78117455063591},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 오정동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-11-25T17:28:36+09:00',
#   'is_new': False}]

# %% [markdown]
# # 1. 원하는 매물이 크롤링 되면 슬랙으로 알람 보내기. 매물 id, title 넣어서 보내주시면 됩니다.

# %%
data_list = []

for data in datas:
    item_id = data['item_id']
    title = data['title']


    
    bang_data = {
        "아이디" : item_id,
        "제목" : title

    }
    
    data_list.append(bang_data)

# %%
df = pd.DataFrame(data_list)
df
# Out:
#           아이디                               제목
# 0    28756928      🏠부평 일신동 신축급관리 안심가능 위치 좋습니다🏠
# 1    29343170        ⭐일신동 18년식 넓은 아파트  막힘없는 뷰⭐
# 2    29670013                     💕💕깔끔✔️부천역세권💕
# 3    29613923           🌈🌈부천역🌈🌈초저렴!!깔끔한 오피스텔 😘
# 4    29617610         🌈🌈부천역 도보5분 최저가 도전 빌트인 깔끔
# ..        ...                              ...
# 709  29667315                  😍삼산고인근😍깨끗😍특올수리😍
# 710  29493481     19년식 준신축 3룸 전세 지하주차장+단지형오피스텔
# 711  29586375  작전역 차량 5분 현대아파트 인근 벍은 구조 투룸 신혼집
# 712  29581493                 베란다 별도 있는 풀옵션 원룸
# 713  29570299                 깨끗하고 신축건물인 풀옵션원룸
#
# [714 rows x 2 columns]

# %%
import json
import pandas as pd

WEBHOOK_URL = "https://hooks.slack.com/services/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"

payload = {
    "channel" : "#api-hook1",
    "username" : "봇",
    "text": str(df[:])

}

requests.post(WEBHOOK_URL, data=json.dumps(payload))
# Out:
# <Response [200]>

# %% [markdown]
# # 2. 검색된 정보에 대한 테이블을 mysql 테이블에 저장

# %%
import MySQLdb

# %%
from sqlalchemy import *
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %%
import pandas as pd

# %%
db = MySQLdb.connect(
    "13.124.155.99",
    "psw",
    "1111",
    "zigbang"
)

db
# Out:
# <_mysql.connection open to '13.124.155.99' at 0000022693F45A70>

# %%
QUERY = """
    SHOW TABLES;
"""

# %%
cursor = db.cursor()
cursor.execute(QUERY) # row의 갯수가 등장한다
# Out:
# 2

# %%
engine = create_engine("mysql://psw:1111@13.124.155.99/zigbang")

# %%
engine
# Out:
# Engine(mysql://psw:***@13.124.155.99/zigbang)

# %%
Base = declarative_base()

class User(Base):
    
    __tablename__ = "user1"
    

    item_id = Column(Integer, primary_key = True)
    title = Column(String(20))

    

    def __init__(self, item_id, title):
        

        self.item_id = item_id
        self.title = title

        

    def __repr__(self):
        return "<User {}, {}, {}, {}>".format(self.item_id, self.title)

# %%
Base.metadata.create_all(engine)

# %%
Session = sessionmaker(engine) 
sess = Session()
sess

# %%
import seaborn as sns
import pandas as pd

# %%
df_zigbang = df

# %%
engine
# Out:
# Engine(mysql://psw:***@13.124.155.99/zigbang)

# %%
df_zigbang.to_sql(name="df",con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5836/3183579779.py in <module>
# ----> 1 df_zigbang.to_sql(name="df",con=engine)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1749         sql_engine = get_engine(engine)
#    1750
# -> 1751         table = self.prep_table(
#    1752             frame=frame,
#    1753             name=name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     856         if self.exists():
#     857             if self.if_exists == "fail":
# --> 858                 raise ValueError(f"Table '{self.name}' already exists.")
#     859             elif self.if_exists == "replace":
#     860                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'df' already exists.

# %% [markdown]
# # 3. folium을 이용해서 지도시각화
# - marker에 정보 입력 필수!

# %%
import folium

# %%
zig = pd.DataFrame(datas)
zig
# Out:
#     section_type   item_id                                images_thumbnail  \
# 0           None  28756928  https://ic.zigbang.com/ic/items/28756928/1.jpg
# 1           None  29343170  https://ic.zigbang.com/ic/items/29343170/1.jpg
# 2           None  29670013  https://ic.zigbang.com/ic/items/29670013/1.jpg
# 3           None  29613923  https://ic.zigbang.com/ic/items/29613923/1.jpg
# 4           None  29617610  https://ic.zigbang.com/ic/items/29617610/1.jpg
# ..           ...       ...                                             ...
# 709         None  29667315  https://ic.zigbang.com/ic/items/29667315/1.jpg
# 710         None  29493481  https://ic.zigbang.com/ic/items/29493481/1.jpg
# 711         None  29586375  https://ic.zigbang.com/ic/items/29586375/1.jpg
# 712         None  29581493  https://ic.zigbang.com/ic/items/29581493/1.jpg
# 713         None  29570299  https://ic.zigbang.com/ic/items/29570299/1.jpg
#
#     sales_type sales_title  deposit  rent  size_m2  \
# 0           전세          전세    36000     0    94.80
# 1           전세          전세    36000     0    63.17
# 2           월세          월세      500    65    49.25
# 3           월세          월세      300    39    39.67
# 4           월세          월세      300    39    39.67
# ..         ...         ...      ...   ...      ...
# 709         매매          매매    11000     0    32.48
# 710         전세          전세    23600     0   104.81
# 711         월세          월세     3500    45    66.12
# 712         월세          월세      500    40    23.14
# 713         월세          월세      300    40    26.45
#
#                             공급면적                        전용면적  ... is_zzim  \
# 0      {'m2': 94.8, 'p': '28.7'}     {'m2': 60, 'p': '18.2'}  ...   False
# 1     {'m2': 63.17, 'p': '19.1'}     {'m2': 60, 'p': '18.2'}  ...   False
# 2     {'m2': 49.25, 'p': '14.9'}    {'m2': 36.36, 'p': '11'}  ...   False
# 3       {'m2': 39.67, 'p': '12'}     {'m2': 19.83, 'p': '6'}  ...   False
# 4       {'m2': 39.67, 'p': '12'}     {'m2': 19.83, 'p': '6'}  ...   False
# ..                           ...                         ...  ...     ...
# 709    {'m2': 32.48, 'p': '9.8'}    {'m2': 29.4, 'p': '8.9'}  ...   False
# 710  {'m2': 104.81, 'p': '31.7'}  {'m2': 64.88, 'p': '19.6'}  ...   False
# 711     {'m2': 66.12, 'p': '20'}     {'m2': 59.5, 'p': '18'}  ...   False
# 712      {'m2': 23.14, 'p': '7'}     {'m2': 23.14, 'p': '7'}  ...   False
# 713      {'m2': 26.45, 'p': '8'}     {'m2': 26.45, 'p': '8'}  ...   False
#
#     status service_type  tags     address1 address2 address3 manage_cost  \
# 0     True           빌라    []  인천시 부평구 일신동     None     None           8
# 1     True           빌라    []  인천시 부평구 일신동     None     None           5
# 2     True         오피스텔    []  경기도 부천시 심곡동     None     None         5.7
# 3     True         오피스텔  [추천]  경기도 부천시 심곡동     None     None         6.2
# 4     True         오피스텔  [추천]  경기도 부천시 심곡동     None     None           6
# ..     ...          ...   ...          ...      ...      ...         ...
# 709   True           빌라    []  인천시 부평구 삼산동     None     None           0
# 710   True         오피스텔  [추천]  인천시 계양구 작전동     None     None           8
# 711   True         오피스텔    []  인천시 계양구 작전동     None     None          13
# 712   True           원룸  [추천]  경기도 부천시 오정동     None     None           3
# 713   True           원룸  [추천]  경기도 부천시 오정동     None     None           5
#
#                       reg_date is_new
# 0    2021-11-08T10:20:29+09:00  False
# 1    2021-11-06T14:26:12+09:00  False
# 2    2021-12-03T13:20:53+09:00   True
# 3    2021-11-29T18:32:11+09:00  False
# 4    2021-11-30T10:48:52+09:00  False
# ..                         ...    ...
# 709  2021-12-03T11:26:32+09:00   True
# 710  2021-11-19T15:12:39+09:00  False
# 711  2021-11-27T09:50:51+09:00  False
# 712  2021-11-26T15:56:22+09:00  False
# 713  2021-11-25T17:28:36+09:00  False
#
# [714 rows x 30 columns]

# %%
cols = zig['random_location'][0].keys()

rows = zig['random_location'].apply(lambda x:list(x.values())) 

zig_loc = pd.DataFrame(rows.values.tolist(), columns=cols)
zig_loc
# Out:
#            lat         lng
# 0    37.485604  126.742769
# 1    37.485620  126.743355
# 2    37.485325  126.778698
# 3    37.485851  126.777165
# 4    37.485840  126.777193
# ..         ...         ...
# 709  37.520730  126.746529
# 710  37.525939  126.739562
# 711  37.526565  126.740671
# 712  37.529297  126.781797
# 713  37.528814  126.781175
#
# [714 rows x 2 columns]

# %%
zig_result = pd.concat([zig,zig_loc],axis=1)
print(zig_result)
# Out:
#     section_type   item_id                                images_thumbnail  \
# 0           None  28756928  https://ic.zigbang.com/ic/items/28756928/1.jpg
# 1           None  29343170  https://ic.zigbang.com/ic/items/29343170/1.jpg
# 2           None  29670013  https://ic.zigbang.com/ic/items/29670013/1.jpg
# 3           None  29613923  https://ic.zigbang.com/ic/items/29613923/1.jpg
# 4           None  29617610  https://ic.zigbang.com/ic/items/29617610/1.jpg
# ..           ...       ...                                             ...
# 709         None  29667315  https://ic.zigbang.com/ic/items/29667315/1.jpg
# 710         None  29493481  https://ic.zigbang.com/ic/items/29493481/1.jpg
# 711         None  29586375  https://ic.zigbang.com/ic/items/29586375/1.jpg
# 712         None  29581493  https://ic.zigbang.com/ic/items/29581493/1.jpg
# 713         None  29570299  https://ic.zigbang.com/ic/items/29570299/1.jpg
#
#     sales_type sales_title  deposit  rent  size_m2  \
# 0           전세          전세    36000     0    94.80
# 1           전세          전세    36000     0    63.17
# 2           월세          월세      500    65    49.25
# 3           월세          월세      300    39    39.67
# 4           월세          월세      300    39    39.67
# ..         ...         ...      ...   ...      ...
# 709         매매          매매    11000     0    32.48
# 710         전세          전세    23600     0   104.81
# 711         월세          월세     3500    45    66.12
# 712         월세          월세      500    40    23.14
# 713         월세          월세      300    40    26.45
#
#                             공급면적                        전용면적  ...  \
# 0      {'m2': 94.8, 'p': '28.7'}     {'m2': 60, 'p': '18.2'}  ...
# 1     {'m2': 63.17, 'p': '19.1'}     {'m2': 60, 'p': '18.2'}  ...
# 2     {'m2': 49.25, 'p': '14.9'}    {'m2': 36.36, 'p': '11'}  ...
# 3       {'m2': 39.67, 'p': '12'}     {'m2': 19.83, 'p': '6'}  ...
# 4       {'m2': 39.67, 'p': '12'}     {'m2': 19.83, 'p': '6'}  ...
# ..                           ...                         ...  ...
# 709    {'m2': 32.48, 'p': '9.8'}    {'m2': 29.4, 'p': '8.9'}  ...
# 710  {'m2': 104.81, 'p': '31.7'}  {'m2': 64.88, 'p': '19.6'}  ...
# 711     {'m2': 66.12, 'p': '20'}     {'m2': 59.5, 'p': '18'}  ...
# 712      {'m2': 23.14, 'p': '7'}     {'m2': 23.14, 'p': '7'}  ...
# 713      {'m2': 26.45, 'p': '8'}     {'m2': 26.45, 'p': '8'}  ...
#
#     service_type  tags     address1 address2 address3 manage_cost  \
# 0             빌라    []  인천시 부평구 일신동     None     None           8
# 1             빌라    []  인천시 부평구 일신동     None     None           5
# 2           오피스텔    []  경기도 부천시 심곡동     None     None         5.7
# 3           오피스텔  [추천]  경기도 부천시 심곡동     None     None         6.2
# 4           오피스텔  [추천]  경기도 부천시 심곡동     None     None           6
# ..           ...   ...          ...      ...      ...         ...
# 709           빌라    []  인천시 부평구 삼산동     None     None           0
# 710         오피스텔  [추천]  인천시 계양구 작전동     None     None           8
# 711         오피스텔    []  인천시 계양구 작전동     None     None          13
# 712           원룸  [추천]  경기도 부천시 오정동     None     None           3
# 713           원룸  [추천]  경기도 부천시 오정동     None     None           5
#
#                       reg_date is_new        lat         lng
# 0    2021-11-08T10:20:29+09:00  False  37.485604  126.742769
# 1    2021-11-06T14:26:12+09:00  False  37.485620  126.743355
# 2    2021-12-03T13:20:53+09:00   True  37.485325  126.778698
# 3    2021-11-29T18:32:11+09:00  False  37.485851  126.777165
# 4    2021-11-30T10:48:52+09:00  False  37.485840  126.777193
# ..                         ...    ...        ...         ...
# 709  2021-12-03T11:26:32+09:00   True  37.520730  126.746529
# 710  2021-11-19T15:12:39+09:00  False  37.525939  126.739562
# 711  2021-11-27T09:50:51+09:00  False  37.526565  126.740671
# 712  2021-11-26T15:56:22+09:00  False  37.529297  126.781797
# 713  2021-11-25T17:28:36+09:00  False  37.528814  126.781175
#
# [714 rows x 32 columns]

# %%
column_names = ["title", "address", "sales_type", "deposit", "rent", "size_m2", "service_type", "manage_cost", "lat", "lng"]
zig_data = zig_result.loc[:, column_names]
zig_data
# Out:
#                                title  address sales_type  deposit  rent  \
# 0        🏠부평 일신동 신축급관리 안심가능 위치 좋습니다🏠  부평구 일신동         전세    36000     0
# 1          ⭐일신동 18년식 넓은 아파트  막힘없는 뷰⭐  부평구 일신동         전세    36000     0
# 2                       💕💕깔끔✔️부천역세권💕  부천시 심곡동         월세      500    65
# 3             🌈🌈부천역🌈🌈초저렴!!깔끔한 오피스텔 😘  부천시 심곡동         월세      300    39
# 4           🌈🌈부천역 도보5분 최저가 도전 빌트인 깔끔  부천시 심곡동         월세      300    39
# ..                               ...      ...        ...      ...   ...
# 709                  😍삼산고인근😍깨끗😍특올수리😍  부평구 삼산동         매매    11000     0
# 710     19년식 준신축 3룸 전세 지하주차장+단지형오피스텔  계양구 작전동         전세    23600     0
# 711  작전역 차량 5분 현대아파트 인근 벍은 구조 투룸 신혼집  계양구 작전동         월세     3500    45
# 712                 베란다 별도 있는 풀옵션 원룸  부천시 오정동         월세      500    40
# 713                 깨끗하고 신축건물인 풀옵션원룸  부천시 오정동         월세      300    40
#
#      size_m2 service_type manage_cost        lat         lng
# 0      94.80           빌라           8  37.485604  126.742769
# 1      63.17           빌라           5  37.485620  126.743355
# 2      49.25         오피스텔         5.7  37.485325  126.778698
# 3      39.67         오피스텔         6.2  37.485851  126.777165
# 4      39.67         오피스텔           6  37.485840  126.777193
# ..       ...          ...         ...        ...         ...
# 709    32.48           빌라           0  37.520730  126.746529
# 710   104.81         오피스텔           8  37.525939  126.739562
# 711    66.12         오피스텔          13  37.526565  126.740671
# 712    23.14           원룸           3  37.529297  126.781797
# 713    26.45           원룸           5  37.528814  126.781175
#
# [714 rows x 10 columns]

# %%
zig_data.reset_index()
# Out:
#      index                            title  address sales_type  deposit  \
# 0        0      🏠부평 일신동 신축급관리 안심가능 위치 좋습니다🏠  부평구 일신동         전세    36000
# 1        1        ⭐일신동 18년식 넓은 아파트  막힘없는 뷰⭐  부평구 일신동         전세    36000
# 2        2                     💕💕깔끔✔️부천역세권💕  부천시 심곡동         월세      500
# 3        3           🌈🌈부천역🌈🌈초저렴!!깔끔한 오피스텔 😘  부천시 심곡동         월세      300
# 4        4         🌈🌈부천역 도보5분 최저가 도전 빌트인 깔끔  부천시 심곡동         월세      300
# ..     ...                              ...      ...        ...      ...
# 709    709                  😍삼산고인근😍깨끗😍특올수리😍  부평구 삼산동         매매    11000
# 710    710     19년식 준신축 3룸 전세 지하주차장+단지형오피스텔  계양구 작전동         전세    23600
# 711    711  작전역 차량 5분 현대아파트 인근 벍은 구조 투룸 신혼집  계양구 작전동         월세     3500
# 712    712                 베란다 별도 있는 풀옵션 원룸  부천시 오정동         월세      500
# 713    713                 깨끗하고 신축건물인 풀옵션원룸  부천시 오정동         월세      300
#
#      rent  size_m2 service_type manage_cost        lat         lng
# 0       0    94.80           빌라           8  37.485604  126.742769
# 1       0    63.17           빌라           5  37.485620  126.743355
# 2      65    49.25         오피스텔         5.7  37.485325  126.778698
# 3      39    39.67         오피스텔         6.2  37.485851  126.777165
# 4      39    39.67         오피스텔           6  37.485840  126.777193
# ..    ...      ...          ...         ...        ...         ...
# 709     0    32.48           빌라           0  37.520730  126.746529
# 710     0   104.81         오피스텔           8  37.525939  126.739562
# 711    45    66.12         오피스텔          13  37.526565  126.740671
# 712    40    23.14           원룸           3  37.529297  126.781797
# 713    40    26.45           원룸           5  37.528814  126.781175
#
# [714 rows x 11 columns]

# %%
zig_data = zig_data.reset_index(drop=True)
zig_data.head()
# Out:
#                          title  address sales_type  deposit  rent  size_m2  \
# 0  🏠부평 일신동 신축급관리 안심가능 위치 좋습니다🏠  부평구 일신동         전세    36000     0    94.80
# 1    ⭐일신동 18년식 넓은 아파트  막힘없는 뷰⭐  부평구 일신동         전세    36000     0    63.17
# 2                 💕💕깔끔✔️부천역세권💕  부천시 심곡동         월세      500    65    49.25
# 3       🌈🌈부천역🌈🌈초저렴!!깔끔한 오피스텔 😘  부천시 심곡동         월세      300    39    39.67
# 4     🌈🌈부천역 도보5분 최저가 도전 빌트인 깔끔  부천시 심곡동         월세      300    39    39.67
#
#   service_type manage_cost        lat         lng
# 0           빌라           8  37.485604  126.742769
# 1           빌라           5  37.485620  126.743355
# 2         오피스텔         5.7  37.485325  126.778698
# 3         오피스텔         6.2  37.485851  126.777165
# 4         오피스텔           6  37.485840  126.777193

# %%
import numpy as np
f_map = folium.Map(location=[37.501553885093806, 126.76776080236965], zoom_start=13)

for idx in zig_data.index:
    lat = zig_data["lat"][idx]
    lng = zig_data["lng"][idx]
    title = zig_data["title"][idx]
    sales_type = zig_data["sales_type"][idx] 
    deposit = zig_data["deposit"][idx]
    rent = zig_data["rent"][idx]
    size_m2 = zig_data["size_m2"][idx]
    service_type = zig_data["service_type"][idx]
    manage_cost = zig_data["manage_cost"][idx]

    folium.Marker(
        location=[lat, lng],
        color='#00FFFF',
        popup=f"{title} / \n 보증금 : {deposit}만원🏠 \n 전월세 : {sales_type} \n 월세 : {rent} \n 평수(m2) : {size_m2} \n 주거형태 : {service_type} \n 관리비 : {manage_cost}",
    ).add_to(f_map)


f_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_86ee77ba390d4d9aa472f6c120801495%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_86ee77ba390d4d9aa472f6c120801495%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_86ee77ba390d4d9aa472f6c120801495%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_86ee77ba390d4d9aa472f6c120801495%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.501553885093806%2C%20126.76776080236965%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

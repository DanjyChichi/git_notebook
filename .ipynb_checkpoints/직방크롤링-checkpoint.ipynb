# %%
import requests
import geohash2
import time
import pandas as pd

# 검색할 주소의 위도와 경도를 얻어내기
addr = "한남동" # 여기 바꾸세요
url = "https://apis.zigbang.com/search?q={}".format(addr)
response = requests.get(url)
data = response.json()["items"][0]
lat, lng = data["lat"], data["lng"]

# geohash 만들어서 해당 지역의 매물을 검색할 수 있도록 함.
geohash = geohash2.encode(lat, lng, precision=5)
house_type = "아파트" # 여기 바꾸세요

url = "https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={}&rent_gteq=0&service_type_eq={}".format(geohash,house_type)
response = requests.get(url)

# item id가 나온다.
item_ids = [data["item_id"] for data in response.json()["items"]]

url = "https://apis.zigbang.com/v2/items/list"
params = {
    "domain": "zigbang",
    "item_ids": item_ids,
    "withCoalition": "true",
}
response = requests.post(url, data=params)
datas = response.json()["items"]

datas
# Out:
# [{'section_type': None,
#   'item_id': 29534653,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29534653/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 40,
#   'size_m2': 31.4,
#   '공급면적': {'m2': 31.4, 'p': '9.5'},
#   '전용면적': {'m2': 30.74, 'p': '9.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '반지하',
#   'floor_string': '반지하',
#   'building_floor': '3',
#   'title': '접근성좋은투룸',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '용산구 보광동',
#   'random_location': {'lat': 37.52965204470926, 'lng': 126.99914956247902},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '서울시 용산구 보광동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-11-23T11:45:01+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29517009,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29517009/1.jpg',
# ...

# %%
import json

WEBHOOK_URL = "https://hooks.slack.com/services/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"

payload = {
    "channel":"#web-hook-demo",
    "username":"박은찬로봇",
    "text":"난 귀여웡"
}

requests.post(WEBHOOK_URL, data=json.dumps(payload))
# Out:
# <Response [200]>

# %% [markdown]
# ## 1. 원하는 매물이 크롤링 되면 슬랙으로 알람 보내기. 매물 id, title 넣어서 보내긔

# %% [markdown]
# # 2. 검색된 정보에 대한 테이블을 mysql에 만들어서 테이블에 저장

# %% [markdown]
# # 3. folium을 이용해서 지도시각화
# * marker에 정보 입력 필수!><

# %%
data_list = []

for data in datas:
    item_id = data['item_id']
    title = data['title']


    
    bang_data = {
        "아이디" : item_id,
        "제목" : title

    }
    
    data_list.append(bang_data)

# %%
df = pd.DataFrame(data_list)
df
# Out:
#           아이디                             제목
# 0    29534653                        접근성좋은투룸
# 1    29517009                       위치 좋은 투룸
# 2    29605604  전입가능 분리형 올인테리어완료 신용산역도보1분 풀옵션
# 3    29658948                       공간 좋은 투룸
# 4    29608564     신용산역도보1분 분리형 테라스 주차가능 전입불가
# ..        ...                            ...
# 795  29666539                💛💙전입신고X💛첫입주💛보안굿
# 796  29670063                 🎀마자막하나🎀보증보험가능🎀
# 797  29673638        🟥🟨🟩🟦전입은 안되지만 최저가로 나왔습니다
# 798  29583207              ★ 귀중한 풀옵션 원룸 전세 ★
# 799  29553054  💕 신축급 깔끔한 오피스텔💕 서울대 병원, 혜화동 💕
#
# [800 rows x 2 columns]

# %%
import json
import pandas as pd

WEBHOOK_URL = "https://hooks.slack.com/services/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"

payload = {
    "channel" : "#api-hook1",
    "username" : "봇",
    "text": str(df[:])

}

requests.post(WEBHOOK_URL, data=json.dumps(payload))
# Out:
# <Response [404]>

# %%
import MySQLdb

# %%
from sqlalchemy import *
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %%
import pandas as pd

# %%
db = MySQLdb.connect(
    "3.36.95.3",
    "yea",
    "1111",
    "zig_bang"
)

db
# Out:
# <_mysql.connection open to '3.36.95.3' at 0x7fb25c041210>

# %%
engine = create_engine("mysql://yea:1111@3.36.95.3/zigbang?charset=utf8")

# %%
engine
# Out:
# Engine(mysql://yea:***@3.36.95.3/zigbang?charset=utf8)

# %%
df_zigbang = df.copy()
df_zigbang
# Out:
#           아이디                             제목
# 0    29534653                        접근성좋은투룸
# 1    29517009                       위치 좋은 투룸
# 2    29605604  전입가능 분리형 올인테리어완료 신용산역도보1분 풀옵션
# 3    29658948                       공간 좋은 투룸
# 4    29608564     신용산역도보1분 분리형 테라스 주차가능 전입불가
# ..        ...                            ...
# 795  29666539                💛💙전입신고X💛첫입주💛보안굿
# 796  29670063                 🎀마자막하나🎀보증보험가능🎀
# 797  29673638        🟥🟨🟩🟦전입은 안되지만 최저가로 나왔습니다
# 798  29583207              ★ 귀중한 풀옵션 원룸 전세 ★
# 799  29553054  💕 신축급 깔끔한 오피스텔💕 서울대 병원, 혜화동 💕
#
# [800 rows x 2 columns]

# %%
df_zigbang.columns = ['id', 'title']

# %%
df_zigbang2 = df_zigbang.copy()
df_zigbang2
# Out:
#            id                          title
# 0    29534653                        접근성좋은투룸
# 1    29517009                       위치 좋은 투룸
# 2    29605604  전입가능 분리형 올인테리어완료 신용산역도보1분 풀옵션
# 3    29658948                       공간 좋은 투룸
# 4    29608564     신용산역도보1분 분리형 테라스 주차가능 전입불가
# ..        ...                            ...
# 795  29666539                💛💙전입신고X💛첫입주💛보안굿
# 796  29670063                 🎀마자막하나🎀보증보험가능🎀
# 797  29673638        🟥🟨🟩🟦전입은 안되지만 최저가로 나왔습니다
# 798  29583207              ★ 귀중한 풀옵션 원룸 전세 ★
# 799  29553054  💕 신축급 깔끔한 오피스텔💕 서울대 병원, 혜화동 💕
#
# [800 rows x 2 columns]

# %%
df_zigbang2.to_sql(name="df", con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/MySQLdb/cursors.py in executemany(self, query, args)
# ...

# %%
from sqlalchemy import *
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

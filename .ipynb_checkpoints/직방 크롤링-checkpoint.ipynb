# %% [markdown]
# !conda install -c conda-forge geohash2

# %%
import requests
import geohash2
import time
import pandas as pd

# 검색할 주소의 위도와 경도를 얻어내기
addr = "삼산동" # 여기 바꾸세요
url = "https://apis.zigbang.com/search?q={}".format(addr)
response = requests.get(url)
data = response.json()["items"][0]
lat, lng = data["lat"], data["lng"]

# geohash 만들어서 해당 지역의 매물을 검색할 수 있도록 함.
geohash = geohash2.encode(lat, lng, precision=5)
house_type = "아파트" # 여기 바꾸세요

url = "https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={}&rent_gteq=0&service_type_eq={}".format(geohash,house_type)
response = requests.get(url)

# item id가 나온다.
item_ids = [data["item_id"] for data in response.json()["items"]]

url = "https://apis.zigbang.com/v2/items/list"
params = {
    "domain": "zigbang",
    "item_ids": item_ids,
    "withCoalition": "true",
}
response = requests.post(url, data=params)
datas = response.json()["items"]

datas
# Out:
# [{'section_type': None,
#   'item_id': 28756928,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/28756928/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 36000,
#   'rent': 0,
#   'size_m2': 94.8,
#   '공급면적': {'m2': 94.8, 'p': '28.7'},
#   '전용면적': {'m2': 60, 'p': '18.2'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '7',
#   'floor_string': '7',
#   'building_floor': '11',
#   'title': '🏠부평 일신동 신축급관리 안심가능 위치 좋습니다🏠',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 일신동',
#   'random_location': {'lat': 37.485146339247656, 'lng': 126.74274674019665},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 일신동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '8',
#   'reg_date': '2021-12-06T09:59:28+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29682534,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29682534/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 36000,
#   'rent': 0,
#   'size_m2': 63.17,
#   '공급면적': {'m2': 63.17, 'p': '19.1'},
#   '전용면적': {'m2': 60, 'p': '18.2'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '7',
#   'floor_string': '7',
#   'building_floor': '10',
#   'title': '⭐일신동 18년식 넓은 아파트  막힘없는 뷰⭐',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 일신동',
#   'random_location': {'lat': 37.48560262176333, 'lng': 126.74338689274408},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 일신동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-12-04T12:51:18+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29670013,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29670013/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 65,
#   'size_m2': 49.25,
#   '공급면적': {'m2': 49.25, 'p': '14.9'},
#   '전용면적': {'m2': 36.36, 'p': '11'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '9',
#   'title': '💕💕깔끔✔️부천역세권💕',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485323495747174, 'lng': 126.77869922977598},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5.7',
#   'reg_date': '2021-12-03T13:20:53+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29613923,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29613923/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 39,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '9',
#   'title': '🌈🌈부천역🌈🌈초저렴!!깔끔한 오피스텔 😘',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48587527213716, 'lng': 126.77718545500929},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6.2',
#   'reg_date': '2021-11-29T18:32:11+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29617610,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29617610/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 39,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '9',
#   'title': '🌈🌈부천역 도보5분 최저가 도전 빌트인 깔끔',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48535430815652, 'lng': 126.77719470279051},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-30T10:48:52+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29665062,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29665062/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 39,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 16.53, 'p': '5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '9',
#   'title': '🟥🟥🟥풀옵션 이중보안 가성비최고 역세권 그라하시티',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48586331087725, 'lng': 126.77778951847019},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-03T10:01:21+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29682465,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29682465/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 39,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '9',
#   'title': '☀☀☀부천역 초 신축!도배+입주청소까지 완료!방상태 초A급',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48535122343839, 'lng': 126.7777995078534},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-04T12:48:23+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29619155,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29619155/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 65,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 33.06, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '8',
#   'floor_string': '8',
#   'building_floor': '9',
#   'title': '역세권 깔끔하고 환한 투룸',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48587691139351, 'lng': 126.77804351683827},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-06T12:37:39+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29361364,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29361364/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 20,
#   'size_m2': 19.83,
#   '공급면적': {'m2': 19.83, 'p': '6'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '4',
#   'title': '역 가깝고 밝은 원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48590609401839, 'lng': 126.77774290722986},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-11-08T16:00:31+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29381169,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29381169/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 35,
#   'size_m2': 37.1,
#   '공급면적': {'m2': 37.1, 'p': '11.2'},
#   '전용면적': {'m2': 20.7, 'p': '6.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '🔷🔷🔷가성비최고🎀풀옵션/보안좋은집/즉시입주',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485962463693454, 'lng': 126.77883426335957},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-10T10:41:51+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29573641,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29573641/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 45,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '☀☀☀부천역 신축을 보증금 100으로??공실!!당장입주가능',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485460153667546, 'lng': 126.77882732957701},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-04T12:48:54+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29608806,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29608806/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 42,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '☀☀☀부천역 초신축 공실!보증금 100! 단기가능!상태A급',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48547304623754, 'lng': 126.77818892439272},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-12-04T12:48:55+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29608818,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29608818/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 40,
#   'rent': 45,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '☀☀☀부천역 신축 무보증!!당장 입주 가능~희귀템!!',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48596091167676, 'lng': 126.77880091921568},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-04T12:38:36+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29613527,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29613527/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 40,
#   'rent': 45,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 16.53, 'p': '5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '🌈🌈오늘 단 하루 이벤트!!보안 좋아요!! 단기가능O',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48546251736618, 'lng': 126.77879524518036},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-29T18:11:24+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29617637,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29617637/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 45,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '🌈🌈부천역 !!최저가 도전 !! 자주식 주차가능합니다!',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48596916317556, 'lng': 126.7788219754927},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-30T10:49:37+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29625422,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29625422/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 35,
#   'size_m2': 37.1,
#   '공급면적': {'m2': 37.1, 'p': '11.2'},
#   '전용면적': {'m2': 20.7, 'p': '6.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '🟦🟥🟩 FULL옵션 원룸 부천역 3분 즉시입주가능',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48546295807487, 'lng': 126.77882687110703},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-30T16:30:00+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29657974,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29657974/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 40,
#   'size_m2': 26.45,
#   '공급면적': {'m2': 26.45, 'p': '8'},
#   '전용면적': {'m2': 14.88, 'p': '4.5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '💖💖단기가능한 깔끔한 오피스텔 💖💖',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48548573414861, 'lng': 126.77821578960685},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-06T16:25:38+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29667166,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29667166/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 42,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 16.53, 'p': '5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '🌈🌈2개월 가능O 자주식 무료주차! 이런게 선착순',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485977689202855, 'lng': 126.77818612246385},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-04T17:29:55+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29696005,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29696005/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 40,
#   'rent': 45,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 19.83, 'p': '6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '저',
#   'floor_string': '저',
#   'building_floor': '10',
#   'title': '☀☀☀부천역 신축을 보증금 무보증으로? 단기 거주도 가능!',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.485475923927005, 'lng': 126.77880712446213},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-06T11:05:38+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29620496,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29620496/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 80,
#   'size_m2': 99.17,
#   '공급면적': {'m2': 99.17, 'p': '30'},
#   '전용면적': {'m2': 95.86, 'p': '29'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '올 리모델링된 주택',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.486115247109055, 'lng': 126.77811784857285},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-06T12:38:26+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29620576,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29620576/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 50,
#   'size_m2': 42.98,
#   '공급면적': {'m2': 42.98, 'p': '13'},
#   '전용면적': {'m2': 39.67, 'p': '12'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '깔끔한 역세권 투룸',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48560372089759, 'lng': 126.77750338733351},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-06T12:38:43+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29652285,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29652285/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 75,
#   'size_m2': 69.42,
#   '공급면적': {'m2': 69.42, 'p': '21'},
#   '전용면적': {'m2': 66.12, 'p': '20'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '*초역세권*공간넓음*',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.4856216107801, 'lng': 126.77810697884668},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-02T11:40:15+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29652308,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29652308/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 50,
#   'size_m2': 46.28,
#   '공급면적': {'m2': 46.28, 'p': '14'},
#   '전용면적': {'m2': 42.98, 'p': '13'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '5',
#   'title': '~💕초역세권~💕깔끔~💕',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48610889091404, 'lng': 126.77745955150061},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-02T11:40:51+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29704655,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29704655/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 38,
#   'size_m2': 33.0578,
#   '공급면적': {'m2': 33.05, 'p': '10'},
#   '전용면적': {'m2': 33.05, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '4',
#   'title': '부천역6분 큰방1,넓은거실,베란다',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48610709783549, 'lng': 126.77606282497197},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-12-06T16:16:26+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29700306,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29700306/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 60,
#   'size_m2': 51.62,
#   '공급면적': {'m2': 51.62, 'p': '15.6'},
#   '전용면적': {'m2': 29.8, 'p': '9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '🟦🟥🟩 풀옵션 1.5룸 부천역 3분거리 보안 잘되는집',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.486135497093656, 'lng': 126.7790864995473},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-12-06T13:33:48+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29700861,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29700861/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 60,
#   'size_m2': 51.64,
#   '공급면적': {'m2': 51.64, 'p': '15.6'},
#   '전용면적': {'m2': 29.79, 'p': '9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '🟥🟥🟥이중보안 풀옵션 초역세권 1.5룸 가성비5짐',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48565733068908, 'lng': 126.77910821839745},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-12-06T13:54:58+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29704310,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29704310/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 7000,
#   'rent': 0,
#   'size_m2': 46.28,
#   '공급면적': {'m2': 46.28, 'p': '14'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '부천역 5분 거의 신축급 원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48565280058448, 'lng': 126.7791197208727},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '8',
#   'reg_date': '2021-12-06T16:04:28+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29705959,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29705959/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 60,
#   'size_m2': 51.62,
#   '공급면적': {'m2': 51.62, 'p': '15.6'},
#   '전용면적': {'m2': 29.8, 'p': '9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '🔷🔷🔷풀옵션1.5룸🎀보안.관리잘되는건물/빠른입주가능',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48613505135014, 'lng': 126.77972023025228},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '8',
#   'reg_date': '2021-12-06T17:02:04+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29432788,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29432788/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 35,
#   'size_m2': 34.05,
#   '공급면적': {'m2': 34.05, 'p': '10.3'},
#   '전용면적': {'m2': 17.54, 'p': '5.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '❤🧡💛💚💙 쁘띠하임  화이트복층 부천대 부천역',
#   'is_first_movein': None,
#   'room_type': '03',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.4858284586067, 'lng': 126.78014282098408},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-15T10:44:46+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29592747,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29592747/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 200,
#   'rent': 35,
#   'size_m2': 34.05,
#   '공급면적': {'m2': 34.05, 'p': '10.3'},
#   '전용면적': {'m2': 17.54, 'p': '5.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '❤🧡💛💚💙화이트 복층 풀옵션 쁘띠하임 깔끔한방 풀옵',
#   'is_first_movein': None,
#   'room_type': '03',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.486310822411774, 'lng': 126.78074945682596},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-11-27T15:51:15+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29702561,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29702561/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 38,
#   'size_m2': 34.05,
#   '공급면적': {'m2': 34.05, 'p': '10.3'},
#   '전용면적': {'m2': 17.54, 'p': '5.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '💕💕저렴&&풀옵션✔️복층❤️❤️',
#   'is_first_movein': None,
#   'room_type': '03',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48578633519337, 'lng': 126.78012675754351},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6.5',
#   'reg_date': '2021-12-06T14:59:56+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29708981,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29708981/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 40,
#   'size_m2': 34.05,
#   '공급면적': {'m2': 34.05, 'p': '10.3'},
#   '전용면적': {'m2': 17.54, 'p': '5.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '10',
#   'title': '❤🧡💛💚💙화이트 복층 쁘띠하임 부천역 부천대 도보',
#   'is_first_movein': None,
#   'room_type': '03',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48628328827949, 'lng': 126.78075237979333},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-06T19:27:03+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29663168,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29663168/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 37,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '1',
#   'floor_string': '1',
#   'building_floor': '3',
#   'title': '부천역5분 주방분리 깔끔한방 가심비좋은방',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48635421520847, 'lng': 126.77813554551032},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-12-02T19:12:15+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29529687,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29529687/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 37,
#   'size_m2': 29.75,
#   '공급면적': {'m2': 29.75, 'p': '9'},
#   '전용면적': {'m2': 29.75, 'p': '9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '1',
#   'floor_string': '1',
#   'building_floor': '4',
#   'title': '♣♣ 밝고 깨끗하고 넓은 주방분리형',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48637221251196, 'lng': 126.77879037136671},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-11-22T18:48:46+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29647348,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29647348/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 27,
#   'size_m2': 12.55,
#   '공급면적': {'m2': 12.55, 'p': '3.8'},
#   '전용면적': {'m2': 12.55, 'p': '3.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '5',
#   'title': '❤️중동, 부천역 원룸 ❤️ 도시형생활주택 ❤️',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48635004951833, 'lng': 126.77357769762567},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-12-01T20:05:07+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29653225,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29653225/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 100,
#   'rent': 35,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '원룸단기 3개월  보100-35,50-38만 부천역5분',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48597936694722, 'lng': 126.77796882258195},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-12-06T09:13:42+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29317638,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29317638/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 30,
#   'size_m2': 23.1405,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '6',
#   'floor_string': '6',
#   'building_floor': '7',
#   'title': '부천역 5분 대로변 엘리베이터있는 깔끔한 원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.486551821181756, 'lng': 126.77886397727171},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-11-06T13:37:26+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29663456,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29663456/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 35,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '5',
#   'floor_string': '5',
#   'building_floor': '5',
#   'title': '♣♣ 해잘드는 초특가원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48609379477143, 'lng': 126.7781302426153},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-02T19:45:47+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29705601,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29705601/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 35,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '1',
#   'floor_string': '1',
#   'building_floor': '3',
#   'title': '♣♣ 올수리 신축급 풀옵션원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48660172772513, 'lng': 126.7786866799241},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-06T16:49:24+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29705622,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29705622/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 30,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '1',
#   'floor_string': '1',
#   'building_floor': '3',
#   'title': '♣♣ 조용하게 살기 좋아요',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48611836895718, 'lng': 126.77801997436394},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-06T17:02:03+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29424818,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29424818/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 50000,
#   'rent': 0,
#   'size_m2': 70.54,
#   '공급면적': {'m2': 70.54, 'p': '21.3'},
#   '전용면적': {'m2': 67.34, 'p': '20.4'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '13',
#   'title': '⭕⭐부천 중동역 신축풀옵션 빌라형아파트⭐⭕',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48660970555795, 'lng': 126.76871147147804},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '4',
#   'reg_date': '2021-11-13T16:22:39+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29434991,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29434991/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 43500,
#   'rent': 0,
#   'size_m2': 93.85,
#   '공급면적': {'m2': 93.85, 'p': '28.4'},
#   '전용면적': {'m2': 59.65, 'p': '18'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '13',
#   'title': '❣💜💛중동역 도보5분💚❤1호선 초역세권💙🧡❣',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48609033653151, 'lng': 126.76870326456493},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '4',
#   'reg_date': '2021-11-15T11:49:38+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29478610,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29478610/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 49000,
#   'rent': 0,
#   'size_m2': 100.4,
#   '공급면적': {'m2': 100.4, 'p': '30.4'},
#   '전용면적': {'m2': 67.34, 'p': '20.4'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '13',
#   'title': '✅중동역✅다양한학군✅편의시설✅학세권',
#   'is_first_movein': None,
#   'room_type': '06',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.486087887002, 'lng': 126.76872864963669},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-11-19T12:37:44+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29492512,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29492512/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 42500,
#   'rent': 0,
#   'size_m2': 85.34,
#   '공급면적': {'m2': 85.34, 'p': '25.8'},
#   '전용면적': {'m2': 59.65, 'p': '18'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '6',
#   'floor_string': '6',
#   'building_floor': '13',
#   'title': '🌈신축첫입주apt🌈잔여세대엑기스🌈중동역도보5분남향집',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.486592299651036, 'lng': 126.76935536179325},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-11-19T12:03:32+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29647142,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29647142/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 41500,
#   'rent': 0,
#   'size_m2': 87.19,
#   '공급면적': {'m2': 87.19, 'p': '26.4'},
#   '전용면적': {'m2': 60.23, 'p': '18.2'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '6',
#   'floor_string': '6',
#   'building_floor': '13',
#   'title': '🔴❤️신축 역세권아파트❤️🔴💜🔵학군밀집지역🔵💜',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48660636006392, 'lng': 126.7687503720986},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-12-01T19:33:30+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29694965,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29694965/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 43500,
#   'rent': 0,
#   'size_m2': 85.95,
#   '공급면적': {'m2': 85.95, 'p': '26'},
#   '전용면적': {'m2': 59.5, 'p': '18'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '14',
#   'title': '❤️신축첫입주❤️즉시입주가능❤️목돈없이마련가능',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48609706836065, 'lng': 126.76870952017178},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-06T10:38:55+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29648163,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29648163/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 26500,
#   'rent': 0,
#   'size_m2': 85,
#   '공급면적': {'m2': 85, 'p': '25.7'},
#   '전용면적': {'m2': 63.16, 'p': '19.1'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '5',
#   'title': '🍀중동역 역세권 인프라 굿 이사비100프로!🍀',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48669648649692, 'lng': 126.76971138081973},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-12-05T16:22:48+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29602754,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29602754/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 45,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '13',
#   'title': '🌈🌈부천역 초 신축 큰대로변!!🌈🌈안심귀가 가능💑',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48672991965237, 'lng': 126.78028195573752},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '7',
#   'reg_date': '2021-12-04T17:29:58+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29655523,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29655523/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 45,
#   'size_m2': 46.28,
#   '공급면적': {'m2': 46.28, 'p': '14'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '13',
#   'title': '☀☀☀부천역 초 신축 가온팰리스 상태 내부상태 초A급^^',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.486231783733786, 'lng': 126.78028051028366},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-02T16:19:55+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29663027,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29663027/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 10500,
#   'rent': 0,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 18, 'p': '5.4'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '13',
#   'title': '부천역3분\r\n전세대출기능한집',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48672415367387, 'lng': 126.78090240843805},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '8',
#   'reg_date': '2021-12-02T18:58:11+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29532105,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29532105/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 26000,
#   'rent': 0,
#   'size_m2': 56.2,
#   '공급면적': {'m2': 56.2, 'p': '17'},
#   '전용면적': {'m2': 37, 'p': '11.2'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '5',
#   'title': '위치 채광최고 좋은 따스한 느낌의 쓰리룸',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.486748004099546, 'lng': 126.77558224616395},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-11-26T11:20:18+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29632471,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29632471/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 26100,
#   'rent': 0,
#   'size_m2': 75.21,
#   '공급면적': {'m2': 75.21, 'p': '22.8'},
#   '전용면적': {'m2': 49.06, 'p': '14.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '5',
#   'title': '중동3룸ㅣ준신축ㅣ최저실입ㅣ역세권ㅣ이사비전부지원',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부천시 중동',
#   'random_location': {'lat': 37.48693727941505, 'lng': 126.7693450767619},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 중동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-12-06T11:08:34+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29618433,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29618433/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 13500,
#   'rent': 0,
#   'size_m2': 92.56,
#   '공급면적': {'m2': 92.56, 'p': '28'},
#   '전용면적': {'m2': 38, 'p': '11.5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '1',
#   'floor_string': '1',
#   'building_floor': '4',
#   'title': '■ 급!!매물 바로 입주가능/부개역세권/쓰리룸',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 부개동',
#   'random_location': {'lat': 37.486482804500454, 'lng': 126.74149248747761},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 부개동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-11-30T11:16:31+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29471191,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29471191/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 1000,
#   'rent': 50,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 33.06, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '부천역도보5분거리 깔끔한1.5룸.',
#   'is_first_movein': None,
#   'room_type': '02',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.486491420021856, 'lng': 126.77918605039213},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '4',
#   'reg_date': '2021-12-06T12:33:58+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29589741,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29589741/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 28,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 33.06, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '2',
#   'floor_string': '2',
#   'building_floor': '5',
#   'title': '월세 500/28',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부평구 부개동',
#   'random_location': {'lat': 37.48651511781875, 'lng': 126.74011063950378},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 부개동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '5',
#   'reg_date': '2021-11-27T12:39:16+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29450347,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29450347/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 300,
#   'rent': 54,
#   'size_m2': 52.89,
#   '공급면적': {'m2': 52.89, 'p': '16'},
#   '전용면적': {'m2': 26.45, 'p': '8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '5',
#   'title': '☀☀☀부천역 초 신축!! 공실~큰대로변~! 깔끔인테리어!',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48703682089537, 'lng': 126.77877409777267},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-04T12:37:37+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29690863,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29690863/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 50,
#   'size_m2': 39,
#   '공급면적': {'m2': 39, 'p': '11.8'},
#   '전용면적': {'m2': 27.5, 'p': '8.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '5',
#   'title': '❤️부천역 오피스텔❤️아주 넓음❤️',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48704065520132, 'lng': 126.77877954307614},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-05T16:53:29+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29691786,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29691786/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 50,
#   'size_m2': 39.26,
#   '공급면적': {'m2': 39.26, 'p': '11.9'},
#   '전용면적': {'m2': 27.5, 'p': '8.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '5',
#   'title': '❤️부천역세권 신축 ❤️ 넓은 오피스텔 ❤️',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48702414336554, 'lng': 126.77942287394467},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
#   'reg_date': '2021-12-05T16:52:28+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29691953,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29691953/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 50,
#   'size_m2': 39,
#   '공급면적': {'m2': 39, 'p': '11.8'},
#   '전용면적': {'m2': 27.5, 'p': '8.3'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '5',
#   'title': '❤️부천역세권 넓은 오피스텔❤️',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 심곡동',
#   'random_location': {'lat': 37.48704659741094, 'lng': 126.77879000354606},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': [],
#   'address1': '경기도 부천시 심곡동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '6',
# ...
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '💖인증매물💖 전체 리모델링 채광좋고 투자가치 좋은집',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52003525378817, 'lng': 126.74618045263603},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-02T13:27:15+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29657741,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29657741/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 33, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '❤️삼산동 한길초교 인접❤️신혼집/특올수리 3룸❤️',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52055175941394, 'lng': 126.74676643854262},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-12-02T15:29:26+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29668189,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29668189/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 38.07,
#   '공급면적': {'m2': 38.07, 'p': '11.5'},
#   '전용면적': {'m2': 32.87, 'p': '9.9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '🌈삼산고인근🌈특올수리🌈 채광굿',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52002322416363, 'lng': 126.74618866142029},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-03T11:57:18+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29680900,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29680900/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 38.07,
#   '공급면적': {'m2': 38.07, 'p': '11.5'},
#   '전용면적': {'m2': 32.87, 'p': '9.9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '삼산고인근 수리 잘된 집',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520523464528395, 'lng': 126.7467647322014},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-04T11:26:05+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29687470,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29687470/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 42.98,
#   '공급면적': {'m2': 42.98, 'p': '13'},
#   '전용면적': {'m2': 33, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '💕한길초인근 올수리 투자 거주굿💕',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520026875298356, 'lng': 126.74618269392779},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-04T17:50:54+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29699192,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29699192/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 13000,
#   'rent': 0,
#   'size_m2': 42.98,
#   '공급면적': {'m2': 42.98, 'p': '13'},
#   '전용면적': {'m2': 33, 'p': '10'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '삼산동 삼산고등학교 인근 인테리어 예쁜 집 금방나가요',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520043287355264, 'lng': 126.74613832089871},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-06T19:06:49+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29637771,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29637771/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 39.67,
#   '공급면적': {'m2': 39.67, 'p': '12'},
#   '전용면적': {'m2': 26.45, 'p': '8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '삼산동 내부특올수리진행 깔끔한투룸매물 중기청100가능',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52072290982333, 'lng': 126.74653398633696},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-01T13:37:54+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29643250,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29643250/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 35,
#   '공급면적': {'m2': 35, 'p': '10.6'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '삼산고등학교 인근 특올수리 채광좋은투룸',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52023227731825, 'lng': 126.7459307189243},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0.5',
#   'reg_date': '2021-12-01T16:46:26+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29654590,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29654590/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 35.08,
#   '공급면적': {'m2': 35.08, 'p': '10.6'},
#   '전용면적': {'m2': 29.4, 'p': '8.9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '★특올수리/구조가 좋음/위치가 좋음★',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52023689013522, 'lng': 126.74650160819759},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-02T13:10:08+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29658779,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29658779/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 49.59,
#   '공급면적': {'m2': 49.59, 'p': '15'},
#   '전용면적': {'m2': 38, 'p': '11.5'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '🔴학세권🟠삼산체육관역🟡고속도로인접🟢채광좋은투룸🔵',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520713410625646, 'lng': 126.74588830403786},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-02T16:00:40+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29662079,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29662079/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 32,
#   '공급면적': {'m2': 32, 'p': '9.7'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '[오늘 확인]✅삼산고,대단지빌라,소액투자,특올수리,채광짱!',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52074956119747, 'lng': 126.74591699007901},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-03T17:00:34+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29667315,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29667315/1.jpg',
#   'sales_type': '매매',
#   'sales_title': '매매',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 32.48,
#   '공급면적': {'m2': 32.48, 'p': '9.8'},
#   '전용면적': {'m2': 29.4, 'p': '8.9'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '😍삼산고인근😍깨끗😍특올수리😍',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52022949394353, 'lng': 126.74650700020571},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': [],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '0',
#   'reg_date': '2021-12-03T11:26:32+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29685066,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29685066/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '＃＃삼산동 신축급 리모델링 투룸 전세대출가능＃＃',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52023418031977, 'lng': 126.74592358319374},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-04T16:22:14+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29696570,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29696570/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 11000,
#   'rent': 0,
#   'size_m2': 34,
#   '공급면적': {'m2': 34, 'p': '10.3'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '삼산동 특리모델링 투룸빌라 전세대출가능 살기좋은동네',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52025285896158, 'lng': 126.74587706218001},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-06T16:10:59+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29706704,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29706704/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '특올수리 되어 깔끔합니다 .  7호선 편함. lh불가',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52023443046138, 'lng': 126.74591629279139},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-06T18:03:48+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29707613,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29707613/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 36.36,
#   '공급면적': {'m2': 36.36, 'p': '11'},
#   '전용면적': {'m2': 27, 'p': '8.2'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '5',
#   'title': '특올수리 인프라좋은 깔끔한 빌라 중기청 100 가능',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.52022596428002, 'lng': 126.74588823569866},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-06T18:36:16+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29708135,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29708135/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 12000,
#   'rent': 0,
#   'size_m2': 33.06,
#   '공급면적': {'m2': 33.06, 'p': '10'},
#   '전용면적': {'m2': 29, 'p': '8.8'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '4',
#   'floor_string': '4',
#   'building_floor': '4',
#   'title': '부평구에서 가장 저렴한 집  특올수리 완료',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '부평구 삼산동',
#   'random_location': {'lat': 37.520227334642726, 'lng': 126.74589455430237},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '빌라',
#   'tags': ['추천'],
#   'address1': '인천시 부평구 삼산동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '1',
#   'reg_date': '2021-12-06T18:25:12+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29493481,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29493481/1.jpg',
#   'sales_type': '전세',
#   'sales_title': '전세',
#   'deposit': 23600,
#   'rent': 0,
#   'size_m2': 104.81,
#   '공급면적': {'m2': 104.81, 'p': '31.7'},
#   '전용면적': {'m2': 64.88, 'p': '19.6'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '중',
#   'floor_string': '중',
#   'building_floor': '14',
#   'title': '19년식 준신축 3룸 전세 지하주차장+단지형오피스텔',
#   'is_first_movein': None,
#   'room_type': '05',
#   'address': '계양구 작전동',
#   'random_location': {'lat': 37.52644957086585, 'lng': 126.73954972618397},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '인천시 계양구 작전동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '8',
#   'reg_date': '2021-11-19T15:12:39+09:00',
#   'is_new': False},
#  {'section_type': None,
#   'item_id': 29693726,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29693726/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 3500,
#   'rent': 45,
#   'size_m2': 66.12,
#   '공급면적': {'m2': 66.12, 'p': '20'},
#   '전용면적': {'m2': 59.5, 'p': '18'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '고',
#   'floor_string': '고',
#   'building_floor': '14',
#   'title': '작전역 차량 5분 현대아파트 인근 벍은 구조 투룸 신혼집',
#   'is_first_movein': None,
#   'room_type': '04',
#   'address': '계양구 작전동',
#   'random_location': {'lat': 37.5260815972952, 'lng': 126.74064868208839},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '오피스텔',
#   'tags': ['추천'],
#   'address1': '인천시 계양구 작전동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '13',
#   'reg_date': '2021-12-06T09:59:26+09:00',
#   'is_new': True},
#  {'section_type': None,
#   'item_id': 29680331,
#   'images_thumbnail': 'https://ic.zigbang.com/ic/items/29680331/1.jpg',
#   'sales_type': '월세',
#   'sales_title': '월세',
#   'deposit': 500,
#   'rent': 40,
#   'size_m2': 23.14,
#   '공급면적': {'m2': 23.14, 'p': '7'},
#   '전용면적': {'m2': 23.14, 'p': '7'},
#   '계약면적': None,
#   'room_type_title': None,
#   'floor': '3',
#   'floor_string': '3',
#   'building_floor': '4',
#   'title': '베란다 별도 있는 풀옵션 원룸',
#   'is_first_movein': None,
#   'room_type': '01',
#   'address': '부천시 오정동',
#   'random_location': {'lat': 37.5287801259303, 'lng': 126.78118416827219},
#   'is_zzim': False,
#   'status': True,
#   'service_type': '원룸',
#   'tags': ['추천'],
#   'address1': '경기도 부천시 오정동',
#   'address2': None,
#   'address3': None,
#   'manage_cost': '3',
#   'reg_date': '2021-12-04T11:00:19+09:00',
#   'is_new': False}]

# %% [markdown]
# # 1. 원하는 매물이 크롤링 되면 슬랙으로 알람 보내기. 매물 id, title 넣어서 보내주시면 됩니다.

# %%
data_list = []

for data in datas:
    item_id = data['item_id']
    title = data['title']


    
    bang_data = {
        "아이디" : item_id,
        "제목" : title

    }
    
    data_list.append(bang_data)

# %%
df = pd.DataFrame(data_list)
df
# Out:
#           아이디                               제목
# 0    28756928      🏠부평 일신동 신축급관리 안심가능 위치 좋습니다🏠
# 1    29682534        ⭐일신동 18년식 넓은 아파트  막힘없는 뷰⭐
# 2    29670013                     💕💕깔끔✔️부천역세권💕
# 3    29613923           🌈🌈부천역🌈🌈초저렴!!깔끔한 오피스텔 😘
# 4    29617610         🌈🌈부천역 도보5분 최저가 도전 빌트인 깔끔
# ..        ...                              ...
# 723  29707613     특올수리 인프라좋은 깔끔한 빌라 중기청 100 가능
# 724  29708135          부평구에서 가장 저렴한 집  특올수리 완료
# 725  29493481     19년식 준신축 3룸 전세 지하주차장+단지형오피스텔
# 726  29693726  작전역 차량 5분 현대아파트 인근 벍은 구조 투룸 신혼집
# 727  29680331                 베란다 별도 있는 풀옵션 원룸
#
# [728 rows x 2 columns]

# %%
import json
import pandas as pd

WEBHOOK_URL = "https://hooks.slack.com/services/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"

payload = {
    "channel" : "#api-hook1",
    "username" : "봇",
    "text": str(df[:])

}

requests.post(WEBHOOK_URL, data=json.dumps(payload))
# Out:
# <Response [200]>

# %% [markdown]
# # 2. 검색된 정보에 대한 테이블을 mysql 테이블에 저장

# %%
import MySQLdb
import mysql.connector

# %%
from sqlalchemy import *
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %%
import pandas as pd

# %%
import mysql.connector

db = mysql.connector.connect(
    host = "15.164.213.213",
    user = "psw",
    password = "1111"
)

cursor = db.cursor()

cursor.execute("CREATE DATABASE zigbang")

# %%
engine = create_engine("mysql://psw:1111@15.164.213.213/zigbang")

# %%
engine
# Out:
# Engine(mysql://psw:***@15.164.213.213/zigbang)

# %%
import seaborn as sns
import pandas as pd

# %%
df_zigbang = df

# %%
df_zigbang.to_sql(name="df",con=engine, if_exists="replace")

# %% [markdown]
# # 3. folium을 이용해서 지도시각화
# - marker에 정보 입력 필수!

# %%
import folium

# %%
zig = pd.DataFrame(datas)
zig
# Out:
#     section_type   item_id                                images_thumbnail  \
# 0           None  28756928  https://ic.zigbang.com/ic/items/28756928/1.jpg
# 1           None  29682534  https://ic.zigbang.com/ic/items/29682534/1.jpg
# 2           None  29670013  https://ic.zigbang.com/ic/items/29670013/1.jpg
# 3           None  29613923  https://ic.zigbang.com/ic/items/29613923/1.jpg
# 4           None  29617610  https://ic.zigbang.com/ic/items/29617610/1.jpg
# ..           ...       ...                                             ...
# 723         None  29707613  https://ic.zigbang.com/ic/items/29707613/1.jpg
# 724         None  29708135  https://ic.zigbang.com/ic/items/29708135/1.jpg
# 725         None  29493481  https://ic.zigbang.com/ic/items/29493481/1.jpg
# 726         None  29693726  https://ic.zigbang.com/ic/items/29693726/1.jpg
# 727         None  29680331  https://ic.zigbang.com/ic/items/29680331/1.jpg
#
#     sales_type sales_title  deposit  rent  size_m2  \
# 0           전세          전세    36000     0    94.80
# 1           전세          전세    36000     0    63.17
# 2           월세          월세      500    65    49.25
# 3           월세          월세      300    39    39.67
# 4           월세          월세      300    39    39.67
# ..         ...         ...      ...   ...      ...
# 723         전세          전세    12000     0    36.36
# 724         전세          전세    12000     0    33.06
# 725         전세          전세    23600     0   104.81
# 726         월세          월세     3500    45    66.12
# 727         월세          월세      500    40    23.14
#
#                             공급면적                        전용면적  ... is_zzim  \
# 0      {'m2': 94.8, 'p': '28.7'}     {'m2': 60, 'p': '18.2'}  ...   False
# 1     {'m2': 63.17, 'p': '19.1'}     {'m2': 60, 'p': '18.2'}  ...   False
# 2     {'m2': 49.25, 'p': '14.9'}    {'m2': 36.36, 'p': '11'}  ...   False
# 3       {'m2': 39.67, 'p': '12'}     {'m2': 19.83, 'p': '6'}  ...   False
# 4       {'m2': 39.67, 'p': '12'}     {'m2': 19.83, 'p': '6'}  ...   False
# ..                           ...                         ...  ...     ...
# 723     {'m2': 36.36, 'p': '11'}      {'m2': 27, 'p': '8.2'}  ...   False
# 724     {'m2': 33.06, 'p': '10'}      {'m2': 29, 'p': '8.8'}  ...   False
# 725  {'m2': 104.81, 'p': '31.7'}  {'m2': 64.88, 'p': '19.6'}  ...   False
# 726     {'m2': 66.12, 'p': '20'}     {'m2': 59.5, 'p': '18'}  ...   False
# 727      {'m2': 23.14, 'p': '7'}     {'m2': 23.14, 'p': '7'}  ...   False
#
#     status service_type  tags     address1 address2 address3 manage_cost  \
# 0     True           빌라    []  인천시 부평구 일신동     None     None           8
# 1     True           빌라    []  인천시 부평구 일신동     None     None           5
# 2     True         오피스텔    []  경기도 부천시 심곡동     None     None         5.7
# 3     True         오피스텔  [추천]  경기도 부천시 심곡동     None     None         6.2
# 4     True         오피스텔  [추천]  경기도 부천시 심곡동     None     None           6
# ..     ...          ...   ...          ...      ...      ...         ...
# 723   True           빌라  [추천]  인천시 부평구 삼산동     None     None           1
# 724   True           빌라  [추천]  인천시 부평구 삼산동     None     None           1
# 725   True         오피스텔  [추천]  인천시 계양구 작전동     None     None           8
# 726   True         오피스텔  [추천]  인천시 계양구 작전동     None     None          13
# 727   True           원룸  [추천]  경기도 부천시 오정동     None     None           3
#
#                       reg_date is_new
# 0    2021-12-06T09:59:28+09:00   True
# 1    2021-12-04T12:51:18+09:00  False
# 2    2021-12-03T13:20:53+09:00  False
# 3    2021-11-29T18:32:11+09:00  False
# 4    2021-11-30T10:48:52+09:00  False
# ..                         ...    ...
# 723  2021-12-06T18:36:16+09:00   True
# 724  2021-12-06T18:25:12+09:00   True
# 725  2021-11-19T15:12:39+09:00  False
# 726  2021-12-06T09:59:26+09:00   True
# 727  2021-12-04T11:00:19+09:00  False
#
# [728 rows x 30 columns]

# %%
cols = zig['random_location'][0].keys()

rows = zig['random_location'].apply(lambda x:list(x.values())) 

zig_loc = pd.DataFrame(rows.values.tolist(), columns=cols)
zig_loc
# Out:
#            lat         lng
# 0    37.485146  126.742747
# 1    37.485603  126.743387
# 2    37.485323  126.778699
# 3    37.485875  126.777185
# 4    37.485354  126.777195
# ..         ...         ...
# 723  37.520226  126.745888
# 724  37.520227  126.745895
# 725  37.526450  126.739550
# 726  37.526082  126.740649
# 727  37.528780  126.781184
#
# [728 rows x 2 columns]

# %%
zig_result = pd.concat([zig,zig_loc],axis=1)
print(zig_result)
# Out:
#     section_type   item_id                                images_thumbnail  \
# 0           None  28756928  https://ic.zigbang.com/ic/items/28756928/1.jpg
# 1           None  29682534  https://ic.zigbang.com/ic/items/29682534/1.jpg
# 2           None  29670013  https://ic.zigbang.com/ic/items/29670013/1.jpg
# 3           None  29613923  https://ic.zigbang.com/ic/items/29613923/1.jpg
# 4           None  29617610  https://ic.zigbang.com/ic/items/29617610/1.jpg
# ..           ...       ...                                             ...
# 723         None  29707613  https://ic.zigbang.com/ic/items/29707613/1.jpg
# 724         None  29708135  https://ic.zigbang.com/ic/items/29708135/1.jpg
# 725         None  29493481  https://ic.zigbang.com/ic/items/29493481/1.jpg
# 726         None  29693726  https://ic.zigbang.com/ic/items/29693726/1.jpg
# 727         None  29680331  https://ic.zigbang.com/ic/items/29680331/1.jpg
#
#     sales_type sales_title  deposit  rent  size_m2  \
# 0           전세          전세    36000     0    94.80
# 1           전세          전세    36000     0    63.17
# 2           월세          월세      500    65    49.25
# 3           월세          월세      300    39    39.67
# 4           월세          월세      300    39    39.67
# ..         ...         ...      ...   ...      ...
# 723         전세          전세    12000     0    36.36
# 724         전세          전세    12000     0    33.06
# 725         전세          전세    23600     0   104.81
# 726         월세          월세     3500    45    66.12
# 727         월세          월세      500    40    23.14
#
#                             공급면적                        전용면적  ...  \
# 0      {'m2': 94.8, 'p': '28.7'}     {'m2': 60, 'p': '18.2'}  ...
# 1     {'m2': 63.17, 'p': '19.1'}     {'m2': 60, 'p': '18.2'}  ...
# 2     {'m2': 49.25, 'p': '14.9'}    {'m2': 36.36, 'p': '11'}  ...
# 3       {'m2': 39.67, 'p': '12'}     {'m2': 19.83, 'p': '6'}  ...
# 4       {'m2': 39.67, 'p': '12'}     {'m2': 19.83, 'p': '6'}  ...
# ..                           ...                         ...  ...
# 723     {'m2': 36.36, 'p': '11'}      {'m2': 27, 'p': '8.2'}  ...
# 724     {'m2': 33.06, 'p': '10'}      {'m2': 29, 'p': '8.8'}  ...
# 725  {'m2': 104.81, 'p': '31.7'}  {'m2': 64.88, 'p': '19.6'}  ...
# 726     {'m2': 66.12, 'p': '20'}     {'m2': 59.5, 'p': '18'}  ...
# 727      {'m2': 23.14, 'p': '7'}     {'m2': 23.14, 'p': '7'}  ...
#
#     service_type  tags     address1 address2 address3 manage_cost  \
# 0             빌라    []  인천시 부평구 일신동     None     None           8
# 1             빌라    []  인천시 부평구 일신동     None     None           5
# 2           오피스텔    []  경기도 부천시 심곡동     None     None         5.7
# 3           오피스텔  [추천]  경기도 부천시 심곡동     None     None         6.2
# 4           오피스텔  [추천]  경기도 부천시 심곡동     None     None           6
# ..           ...   ...          ...      ...      ...         ...
# 723           빌라  [추천]  인천시 부평구 삼산동     None     None           1
# 724           빌라  [추천]  인천시 부평구 삼산동     None     None           1
# 725         오피스텔  [추천]  인천시 계양구 작전동     None     None           8
# 726         오피스텔  [추천]  인천시 계양구 작전동     None     None          13
# 727           원룸  [추천]  경기도 부천시 오정동     None     None           3
#
#                       reg_date is_new        lat         lng
# 0    2021-12-06T09:59:28+09:00   True  37.485146  126.742747
# 1    2021-12-04T12:51:18+09:00  False  37.485603  126.743387
# 2    2021-12-03T13:20:53+09:00  False  37.485323  126.778699
# 3    2021-11-29T18:32:11+09:00  False  37.485875  126.777185
# 4    2021-11-30T10:48:52+09:00  False  37.485354  126.777195
# ..                         ...    ...        ...         ...
# 723  2021-12-06T18:36:16+09:00   True  37.520226  126.745888
# 724  2021-12-06T18:25:12+09:00   True  37.520227  126.745895
# 725  2021-11-19T15:12:39+09:00  False  37.526450  126.739550
# 726  2021-12-06T09:59:26+09:00   True  37.526082  126.740649
# 727  2021-12-04T11:00:19+09:00  False  37.528780  126.781184
#
# [728 rows x 32 columns]

# %%
column_names = ["title", "address", "sales_type", "deposit", "rent", "size_m2", "service_type", "manage_cost", "lat", "lng"]
zig_data = zig_result.loc[:, column_names]
zig_data
# Out:
#                                title  address sales_type  deposit  rent  \
# 0        🏠부평 일신동 신축급관리 안심가능 위치 좋습니다🏠  부평구 일신동         전세    36000     0
# 1          ⭐일신동 18년식 넓은 아파트  막힘없는 뷰⭐  부평구 일신동         전세    36000     0
# 2                       💕💕깔끔✔️부천역세권💕  부천시 심곡동         월세      500    65
# 3             🌈🌈부천역🌈🌈초저렴!!깔끔한 오피스텔 😘  부천시 심곡동         월세      300    39
# 4           🌈🌈부천역 도보5분 최저가 도전 빌트인 깔끔  부천시 심곡동         월세      300    39
# ..                               ...      ...        ...      ...   ...
# 723     특올수리 인프라좋은 깔끔한 빌라 중기청 100 가능  부평구 삼산동         전세    12000     0
# 724          부평구에서 가장 저렴한 집  특올수리 완료  부평구 삼산동         전세    12000     0
# 725     19년식 준신축 3룸 전세 지하주차장+단지형오피스텔  계양구 작전동         전세    23600     0
# 726  작전역 차량 5분 현대아파트 인근 벍은 구조 투룸 신혼집  계양구 작전동         월세     3500    45
# 727                 베란다 별도 있는 풀옵션 원룸  부천시 오정동         월세      500    40
#
#      size_m2 service_type manage_cost        lat         lng
# 0      94.80           빌라           8  37.485146  126.742747
# 1      63.17           빌라           5  37.485603  126.743387
# 2      49.25         오피스텔         5.7  37.485323  126.778699
# 3      39.67         오피스텔         6.2  37.485875  126.777185
# 4      39.67         오피스텔           6  37.485354  126.777195
# ..       ...          ...         ...        ...         ...
# 723    36.36           빌라           1  37.520226  126.745888
# 724    33.06           빌라           1  37.520227  126.745895
# 725   104.81         오피스텔           8  37.526450  126.739550
# 726    66.12         오피스텔          13  37.526082  126.740649
# 727    23.14           원룸           3  37.528780  126.781184
#
# [728 rows x 10 columns]

# %%
zig_data.reset_index()
# Out:
#      index                            title  address sales_type  deposit  \
# 0        0      🏠부평 일신동 신축급관리 안심가능 위치 좋습니다🏠  부평구 일신동         전세    36000
# 1        1        ⭐일신동 18년식 넓은 아파트  막힘없는 뷰⭐  부평구 일신동         전세    36000
# 2        2                     💕💕깔끔✔️부천역세권💕  부천시 심곡동         월세      500
# 3        3           🌈🌈부천역🌈🌈초저렴!!깔끔한 오피스텔 😘  부천시 심곡동         월세      300
# 4        4         🌈🌈부천역 도보5분 최저가 도전 빌트인 깔끔  부천시 심곡동         월세      300
# ..     ...                              ...      ...        ...      ...
# 723    723     특올수리 인프라좋은 깔끔한 빌라 중기청 100 가능  부평구 삼산동         전세    12000
# 724    724          부평구에서 가장 저렴한 집  특올수리 완료  부평구 삼산동         전세    12000
# 725    725     19년식 준신축 3룸 전세 지하주차장+단지형오피스텔  계양구 작전동         전세    23600
# 726    726  작전역 차량 5분 현대아파트 인근 벍은 구조 투룸 신혼집  계양구 작전동         월세     3500
# 727    727                 베란다 별도 있는 풀옵션 원룸  부천시 오정동         월세      500
#
#      rent  size_m2 service_type manage_cost        lat         lng
# 0       0    94.80           빌라           8  37.485146  126.742747
# 1       0    63.17           빌라           5  37.485603  126.743387
# 2      65    49.25         오피스텔         5.7  37.485323  126.778699
# 3      39    39.67         오피스텔         6.2  37.485875  126.777185
# 4      39    39.67         오피스텔           6  37.485354  126.777195
# ..    ...      ...          ...         ...        ...         ...
# 723     0    36.36           빌라           1  37.520226  126.745888
# 724     0    33.06           빌라           1  37.520227  126.745895
# 725     0   104.81         오피스텔           8  37.526450  126.739550
# 726    45    66.12         오피스텔          13  37.526082  126.740649
# 727    40    23.14           원룸           3  37.528780  126.781184
#
# [728 rows x 11 columns]

# %%
zig_data = zig_data.reset_index(drop=True)
zig_data.head()
# Out:
#                          title  address sales_type  deposit  rent  size_m2  \
# 0  🏠부평 일신동 신축급관리 안심가능 위치 좋습니다🏠  부평구 일신동         전세    36000     0    94.80
# 1    ⭐일신동 18년식 넓은 아파트  막힘없는 뷰⭐  부평구 일신동         전세    36000     0    63.17
# 2                 💕💕깔끔✔️부천역세권💕  부천시 심곡동         월세      500    65    49.25
# 3       🌈🌈부천역🌈🌈초저렴!!깔끔한 오피스텔 😘  부천시 심곡동         월세      300    39    39.67
# 4     🌈🌈부천역 도보5분 최저가 도전 빌트인 깔끔  부천시 심곡동         월세      300    39    39.67
#
#   service_type manage_cost        lat         lng
# 0           빌라           8  37.485146  126.742747
# 1           빌라           5  37.485603  126.743387
# 2         오피스텔         5.7  37.485323  126.778699
# 3         오피스텔         6.2  37.485875  126.777185
# 4         오피스텔           6  37.485354  126.777195

# %%
### import numpy as np
f_map = folium.Map(location=[37.501553885093806, 126.76776080236965], zoom_start=13)

for idx in zig_data.index:
    lat = zig_data["lat"][idx]
    lng = zig_data["lng"][idx]
    title = zig_data["title"][idx]
    sales_type = zig_data["sales_type"][idx] 
    deposit = zig_data["deposit"][idx]
    rent = zig_data["rent"][idx]
    size_m2 = zig_data["size_m2"][idx]
    service_type = zig_data["service_type"][idx]
    manage_cost = zig_data["manage_cost"][idx]

    folium.Marker(
        location=[lat, lng],
        color='#00FFFF',
        popup=f"{title} / \n 보증금 : {deposit}만원🏠 \n 전월세 : {sales_type} \n 월세 : {rent} \n 평수(m2) : {size_m2} \n 주거형태 : {service_type} \n 관리비 : {manage_cost}",
    ).add_to(f_map)


f_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0efdbba169cc4c2f96fd9e21b3c3808a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0efdbba169cc4c2f96fd9e21b3c3808a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0efdbba169cc4c2f96fd9e21b3c3808a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0efdbba169cc4c2f96fd9e21b3c3808a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.501553885093806%2C%20126.76776080236965%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ###
